# %% [markdown]
# <a href="https://colab.research.google.com/github/sergiobm3/ESI_MachineLearning/blob/NLP/TFIDF%2BN_GRAMS%2BPOS%2BOTHER_FEATURES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # 0. Introduction
#
# In this notebook we will work with the following configuration when doing vectorization: **TFIDF + N-grams + POS Tagging + Other features**
#
# The objective of this notebook is to classify the tweets *(pre-processed)* by applying various classification algorithms to the vectorized data.

# %% [markdown]
# ## Libraries

# %%
import io
import pandas as pd
from google.colab import files
import re
import numpy as np

from ast import literal_eval
import nltk
from sklearn.utils.multiclass import unique_labels
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectKBest, chi2, f_regression, mutual_info_classif
from sklearn.model_selection import train_test_split

from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB, ComplementNB
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

from nltk.tokenize.treebank import TreebankWordDetokenizer

# %% [markdown]
# ## 1. Loading Data
#
# We start by loading the data file that contains the preprocessing tweets with which the study will work. The file format to upload is CSV.
#
# For this purpose, you must have the *preprocessed_data.csv* file loaded in this notebook.

# %%
df = pd.read_csv('./prepocessed_data.csv', sep=',')

with_e = []
without_e = []
for i in range(0,len(df)):
  without_e.append(literal_eval(df.iloc[i]['preprocessing_without_emoticons']))
  with_e.append(literal_eval(df.iloc[i]['preprocessing_with_emoticons']))

df['preprocessing_without_emoticons'] = without_e
df['preprocessing_with_emoticons'] = with_e
df = df.drop(columns=['Unnamed: 0'])
df
# Out:
#                          preprocessing_without_emoticons  ... class
# 0      [a, a, woman, you, should, not, complain, abou...  ...     2
# 1      [boy, day, cold, tea, down, bad, for, coffin, ...  ...     1
# 2      [dawn, you, ever, fuck, a, bitch, and, she, st...  ...     1
# 3                           [she, look, like, a, tranny]  ...     1
# 4      [the, shit, you, hear, about, me, might, be, t...  ...     1
# ...                                                  ...  ...   ...
# 24778  [you, a, mutual, in, lie, right, his, to, is, ...  ...     1
# 24779  [you, have, gone, and, broke, the, wrong, hear...  ...     2
# 24780  [young, buck, anna, eat, dat, nigh, like, i, a...  ...     1
# 24781         [you, got, wild, bitch, telling, you, lie]  ...     1
# 24782  [ruffled, near, eleven, dahlia, beautiful, col...  ...     2
#
# [24783 rows x 3 columns]

# %% [markdown]
# # 2. Vectorization
#
# When the tweets are preprocessed, we can start to obtain information from them.
#
# The goal of this section is to obtain a dataframe with all the information which will be used for the next one, in order to classify the tweets.

# %% [markdown]
# ## TFIDF + N-grams
#
# In order to start using TFIDF, we will first have to create a TFIDFVectorizer.
#
# With Tfidfvectorizer you compute the word counts, idf and tf-idf values all at once. Three steps at once.
#
# In addition, the N-grams will now be added to it.

# %%
def identity_tokenizer(text):
    return text

vectorizer = TfidfVectorizer(tokenizer = identity_tokenizer,min_df=0.01, ngram_range= (1,3),lowercase=False)
X_TFIDF = vectorizer.fit_transform(df['preprocessing_without_emoticons'])
X_TFIDF
# Out:
# <24783x225 sparse matrix of type '<class 'numpy.float64'>'
# 	with 211769 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## POS tagging

# %%
nltk.download('averaged_perceptron_tagger')

list_POS = []
for tweet in df['preprocessing_without_emoticons']:
  sentence = []
  for sent in nltk.pos_tag(tweet):
    sentence.append(sent[1])
  list_POS.append(sentence)
list_POS
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [['DT',
#   'DT',
#   'NN',
#   'PRP',
#   'MD',
#   'RB',
#   'VB',
#   'IN',
#   'VBG',
#   'RP',
#   'PRP$',
#   'NN',
#   'DT',
#   'DT',
#   'NN',
#   'PRP',
#   'MD',
#   'RB',
#   'VB',
#   'DT',
#   'NN',
#   'RP'],
#  ['JJ',
#   'NN',
#   'VB',
#   'NN',
#   'RP',
#   'JJ',
#   'IN',
#   'NN',
#   'NN',
#   'PRP',
#   'IN',
#   'DT',
#   'JJ',
#   'NN'],
#  ['NN',
#   'PRP',
#   'RB',
#   'VBD',
#   'DT',
#   'NN',
#   'CC',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'PRP',
#   'VB',
#   'VBN',
#   'DT',
#   'NN'],
#  ['PRP', 'VBP', 'IN', 'DT', 'NN'],
#  ['DT',
#   'NN',
#   'PRP',
#   'VBP',
#   'IN',
#   'PRP',
#   'MD',
#   'VB',
#   'JJ',
#   'CC',
#   'PRP',
#   'MD',
#   'VB',
#   'JJR',
#   'IN',
#   'DT',
#   'NN',
#   'WP',
#   'VBD',
#   'PRP',
#   'TO',
#   'DT'],
#  ['DT',
#   'NN',
#   'RB',
#   'VB',
#   'PRP',
#   'NN',
#   'PRP',
#   'RB',
#   'JJ',
#   'CC',
#   'RB',
#   'IN',
#   'NN',
#   'CC',
#   'RB',
#   'VBG',
#   'IN',
#   'JJ',
#   'IN',
#   'IN',
#   'NN'],
#  ['NN',
#   'MD',
#   'RB',
#   'RB',
#   'VB',
#   'RP',
#   'CC',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'VBD',
#   'RB',
#   'JJ',
#   'NN',
#   'VBG',
#   'IN'],
#  ['NN',
#   'NN',
#   'VBP',
#   'VBN',
#   'IN',
#   'PRP',
#   'JJ',
#   'NN',
#   'VBG',
#   'IN',
#   'JJ',
#   'JJ',
#   'NN'],
#  ['PRP', 'MD', 'RB', 'VB', 'DT', 'NN', 'RP', 'IN', 'DT'],
#  ['NN', 'VBP', 'VBG', 'NNS', 'NN'],
#  ['NN',
#   'VBZ',
#   'DT',
#   'NN',
#   'PRP',
#   'VBD',
#   'NN',
#   'NN',
#   'NN',
#   'VBD',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN'],
#  ['NN', 'NN', 'NN', 'PRP', 'VBD', 'NN'],
#  ['RB', 'JJ', 'IN', 'NN', 'VBP', 'VBZ', 'RB', 'VB', 'IN', 'IN'],
#  ['JJ', 'NN', 'VBZ', 'DT', 'JJ', 'NN', 'IN', 'NN', 'IN'],
#  ['NN', 'VB', 'RP', 'IN', 'PRP'],
#  ['NN', 'NN', 'VB', 'PRP', 'IN', 'PRP'],
#  ['NN', 'NN', 'WDT'],
#  ['NN', 'WP', 'VBP', 'PRP', 'VB'],
#  ['NN', 'VB', 'VBN', 'RP', 'JJ', 'NN'],
#  ['JJ', 'NN', 'DT', 'JJ', 'NN'],
#  ['VBD', 'NN', 'MD', 'VB', 'PRP', 'NN'],
#  ['NN', 'WDT', 'VBP', 'IN', 'CD'],
#  ['MD', 'PRP', 'VB', 'DT', 'VB', 'NN', 'NN'],
#  ['NN',
#   'DT',
#   'WDT',
#   'VBP',
#   'VB',
#   'RB',
#   'JJ',
#   'JJ',
#   'NN',
#   'IN',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'NN',
#   'TO',
#   'VB',
#   'IN',
#   'RP'],
#  ['VBD', 'DT', 'NN', 'NN', 'VBG', 'IN', 'PRP$', 'NN', 'NN', 'NN'],
#  ['PRP$', 'JJ', 'NN', 'IN', 'JJ', 'NN'],
#  ['PRP', 'WP', 'PRP', 'VBG', 'IN'],
#  ['NN',
#   'VBD',
#   'IN',
#   'NN',
#   'IN',
#   'JJ',
#   'NN',
#   'NN',
#   'VBD',
#   'IN',
#   'NN',
#   'DT',
#   'NN'],
#  ['NNS', 'VBP', 'DT', 'JJ', 'NN', 'WP', 'VBP', 'IN', 'NN'],
#  ['JJ', 'VBP', 'PRP$', 'NN', 'WRB', 'NN', 'VBP', 'NN', 'PRP', 'PRP$', 'NN'],
#  ['NN', 'VBP', 'PRP$', 'JJ', 'NN', 'PRP$', 'JJ', 'NN', 'NN', 'NN'],
#  ['NN',
#   'MD',
#   'VB',
#   'IN',
#   'RB',
#   'TO',
#   'DT',
#   'JJ',
#   'PRP',
#   'CC',
#   'PRP$',
#   'JJ',
#   'NN',
#   'MD',
#   'VB',
#   'JJ'],
#  ['IN', 'PRP', 'VBP', 'IN', 'DT', 'NN', 'NN', 'JJ', 'NN', 'VBD', 'RP'],
#  ['IN', 'PRP', 'VBP', 'JJ', 'NN', 'VBN', 'PRP', 'VBP', 'JJ'],
#  ['IN',
#   'VBN',
#   'IN',
#   'JJ',
#   'NN',
#   'PRP',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'IN',
#   'PRP',
#   'DT',
#   'JJ',
#   'NN',
#   'EX',
#   'DT',
#   'NN',
#   'IN',
#   'DT'],
#  ['VBZ', 'IN', 'DT', 'NN'],
#  ['PRP', 'VBZ', 'NN', 'TO', 'VB', 'DT', 'NN', 'IN'],
#  ['RB', 'VB', 'NN', 'RB', 'PRP', 'DT', 'NN', 'IN', 'NN'],
#  ['NNS', 'VBP', 'IN', 'NN', 'IN', 'NN', 'IN', 'DT', 'NN'],
#  ['IN', 'NN', 'VBD', 'IN', 'PRP', 'VBP', 'IN', 'DT', 'NNS'],
#  ['NN', 'VBD', 'DT', 'JJ', 'NN', 'IN', 'PRP$', 'NN'],
#  ['RBS', 'VBN', 'CC', 'DT', 'NN', 'NN'],
#  ['JJ',
#   'NN',
#   'JJ',
#   'VB',
#   'PRP',
#   'VB',
#   'JJ',
#   'JJ',
#   'IN',
#   'PRP',
#   'JJ',
#   'JJ',
#   'NN',
#   'RP',
#   'RB',
#   'JJ',
#   'IN',
#   'JJ',
#   'JJ',
#   'NN'],
#  ['VB', 'RP', 'VB', 'IN', 'RB', 'IN', 'JJ', 'NN'],
#  ['NN', 'DT', 'NN', 'IN', 'DT', 'JJ', 'NN', 'IN'],
#  ['NN', 'VBZ', 'DT', 'JJ', 'NN'],
#  ['JJ', 'NN', 'IN', 'NN', 'NN', 'PRP', 'DT', 'NN', 'IN'],
#  ['VBG',
#   'NN',
#   'RB',
#   'IN',
#   'DT',
#   'NN',
#   'JJ',
#   'NN',
#   'WDT',
#   'NN',
#   'TO',
#   'VB',
#   'JJ'],
#  ['DT', 'VB', 'RB', 'JJS', 'PRP', 'MD', 'VB', 'PRP', 'VB', 'IN', 'PRP'],
#  ['DT', 'NNS', 'IN', 'NN', 'WDT', 'VBP', 'NN', 'RB', 'VB', 'IN', 'PRP'],
#  ['PRP', 'VBP', 'JJ', 'DT', 'NN', 'PDT', 'DT', 'NN'],
#  ['DT', 'NN', 'SYM', 'VBG', 'NN', 'NN', 'DT', 'VBP', 'RB', 'VBP', 'NN'],
#  ['PRP',
#   'VBP',
#   'DT',
#   'NN',
#   'DT',
#   'VBP',
#   'NN',
#   'NN',
#   'VBD',
#   'RP',
#   'JJ',
#   'CC',
#   'VBN',
#   'TO',
#   'VB',
#   'JJ',
#   'NN'],
#  ['JJ', 'NN', 'VB', 'DT', 'NN', 'NN', 'PRP$', 'NN'],
#  ['IN',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   'RB',
#   'JJR',
#   'IN',
#   'JJS',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'CC'],
#  ['IN',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   'MD',
#   'RB',
#   'VB',
#   'TO',
#   'VB',
#   'IN',
#   'NN',
#   'NN'],
#  ['IN',
#   'JJ',
#   'NN',
#   'CC',
#   'NN',
#   'VB',
#   'PRP$',
#   'NN',
#   'RB',
#   'VB',
#   'PRP',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'NN',
#   'IN',
#   'PRP',
#   'DT',
#   'NN',
#   'PRP',
#   'MD',
#   'VB',
#   'PRP'],
#  ['PRP', 'VBZ', 'VBN', 'RB', 'VB', 'DT', 'PRP'],
#  ['NN', 'IN', 'DT', 'NN', 'VBD', 'PRP$', 'JJ', 'NN', 'NN', 'IN', 'DT', 'NN'],
#  ['DT',
#   'NN',
#   'VBP',
#   'VBP',
#   'VBZ',
#   'VB',
#   'NN',
#   'CC',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   'NNS'],
#  ['NN',
#   'RB',
#   'VBD',
#   'JJ',
#   'NN',
#   'NN',
#   'DT',
#   'RB',
#   'IN',
#   'PRP',
#   'VBP',
#   'NNS',
#   'VBP',
#   'TO',
#   'VB',
#   'IN',
#   'NN',
#   'IN',
#   'NN',
#   'IN'],
#  ['NN', 'VBP', 'DT', 'NN', 'NN', 'PRP', 'VBD'],
#  ['JJ',
#   'VBP',
#   'VBG',
#   'DT',
#   'NN',
#   'VBZ',
#   'VBN',
#   'RB',
#   'WRB',
#   'JJ',
#   'VBG',
#   'DT',
#   'JJ',
#   'VBP',
#   'PRP',
#   'DT',
#   'NN'],
#  ['NNS', 'VBP', 'JJ', 'JJ', 'NN', 'NN'],
#  ['VB', 'DT', 'RB', 'VBN', 'PRP$', 'NN', 'IN', 'JJ', 'NN', 'DT', 'NN', 'NNS'],
#  ['WRB',
#   'JJ',
#   'VBN',
#   'NN',
#   'CC',
#   'NN',
#   'NN',
#   'TO',
#   'DT',
#   'NN',
#   'WRB',
#   'PRP',
#   'VBP',
#   'DT',
#   'IN',
#   'NN',
#   'IN',
#   'JJ',
#   'VBP'],
#  ['NN', 'NN', 'CC', 'JJ', 'NN'],
#  ['RB', 'VB', 'DT', 'NN', 'VBP', 'DT', 'VB', 'CD', 'NN', 'NN'],
#  ['NN', 'NN', 'JJ', 'RB', 'PRP', 'MD', 'VB', 'JJR', 'RB'],
#  ['RB',
#   'JJ',
#   'RB',
#   'NN',
#   'NN',
#   'IN',
#   'NN',
#   'MD',
#   'PRP',
#   'VB',
#   'VB',
#   'JJ',
#   'NN'],
#  ['WRB',
#   'DT',
#   'NN',
#   'CC',
#   'NN',
#   'NN',
#   'PRP',
#   'VBZ',
#   'PRP',
#   'VBD',
#   'IN',
#   'NN',
#   'MD'],
#  ['NN', 'NN', 'PRP', 'WDT', 'VBZ', 'CD', 'NN', 'NN'],
#  ['PRP', 'PRP', 'PRP', 'JJ', 'NN', 'RB', 'DT', 'JJR', 'NN', 'MD'],
#  ['CC',
#   'DT',
#   'NN',
#   'TO',
#   'VB',
#   'IN',
#   'NN',
#   'NN',
#   'RB',
#   'VBN',
#   'IN',
#   'DT',
#   'NN',
#   'RB',
#   'VBD',
#   'DT',
#   'RBS',
#   'NN',
#   'NN'],
#  ['TO',
#   'VB',
#   'VBG',
#   'DT',
#   'PRP',
#   'DT',
#   'DT',
#   'NN',
#   'VBG',
#   'NN',
#   'NN',
#   'NN',
#   'VBZ',
#   'NN'],
#  ['NN', 'NN', 'NN', 'JJ', 'DT', 'VBZ', 'RB', 'JJ'],
#  ['IN', 'IN', 'NN', 'NN', 'VBP', 'VBN', 'RB', 'JJ', 'NN'],
#  ['JJ',
#   'RB',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'CC',
#   'VB',
#   'VB',
#   'WP',
#   'IN',
#   'DT',
#   'VBZ',
#   'NN',
#   'IN',
#   'PRP$',
#   'NN',
#   'TO',
#   'VB',
#   'DT',
#   'JJ',
#   'DT',
#   'VBZ',
#   'MD',
#   'VB',
#   'NN'],
#  ['VBG', 'NN', 'NN', 'NN'],
#  ['NN',
#   'NN',
#   'JJ',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'CC',
#   'DT',
#   'DT',
#   'NN',
#   'VBG',
#   'RP',
#   'DT',
#   'NN',
#   'VBD',
#   'JJ'],
#  ['DT',
#   'NN',
#   'IN',
#   'NN',
#   'NN',
#   'PRP',
#   'VBZ',
#   'DT',
#   'NN',
#   'IN',
#   'RB',
#   'VBG',
#   'PRP',
#   'JJ'],
#  ['NN',
#   'VB',
#   'VBG',
#   'TO',
#   'VB',
#   'IN',
#   'NN',
#   'RB',
#   'JJ',
#   'IN',
#   'JJ',
#   'NN',
#   'NN',
#   'CC',
#   'NN',
#   'NN',
#   'IN',
#   'NN'],
#  ['VB', 'JJ', 'NN', 'NN', 'NN'],
#  ['RB',
#   'VBZ',
#   'VBP',
#   'VBN',
#   'VBP',
#   'DT',
#   'JJ',
#   'NN',
#   'NN',
#   'PRP',
#   'VBZ',
#   'DT',
#   'PRP'],
#  ['IN',
#   'PRP$',
#   'PRP',
#   'MD',
#   'RB',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   'NN',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'PRP',
#   'WRB',
#   'PRP',
#   'NN',
#   'IN',
#   'PRP$'],
#  ['NN', 'NN'],
#  ['RB',
#   'VB',
#   'PRP$',
#   'NN',
#   'IN',
#   'NN',
#   'NN',
#   'PRP',
#   'VBZ',
#   'RB',
#   'RB',
#   'JJ',
#   'NN'],
#  ['DT', 'NN', 'NN', 'RB', 'JJ', 'NN', 'NN'],
#  ['RB', 'VBN', 'VBN', 'TO', 'VB'],
#  ['NN', 'PRP', 'DT', 'NN', 'NN', 'PRP', 'MD', 'VB', 'PRP', 'DT', 'JJ'],
#  ['JJ', 'NN', 'VBD', 'NNS', 'TO'],
#  ['WRB',
#   'CC',
#   'RB',
#   'VB',
#   'RP',
#   'DT',
#   'NN',
#   'VBP',
#   'VBN',
#   'DT',
#   'NN',
#   'NN',
#   'TO',
#   'VB'],
#  ['DT',
#   'VBZ',
#   'VBP',
#   'VBG',
#   'IN',
#   'PRP',
#   'VBZ',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'VBD',
#   'NN',
#   'NN'],
#  ['WP',
#   'MD',
#   'PRP',
#   'DT',
#   'VBP',
#   'RB',
#   'RB',
#   'VBN',
#   'NN',
#   'VBP',
#   'IN',
#   'PRP',
#   'VBP',
#   'VBG',
#   'NNS',
#   'VB'],
#  ['NN',
#   'RBR',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'JJ',
#   'MD',
#   'VB',
#   'NN',
#   'CC',
#   'NN',
#   'PRP',
#   'JJR',
#   'VB',
#   'VBG',
#   'PRP$',
#   'NN'],
#  ['VBG',
#   'RB',
#   'TO',
#   'NN',
#   'RB',
#   'RBR',
#   'JJ',
#   'IN',
#   'DT',
#   'NN',
#   'WP',
#   'VBP',
#   'PRP'],
#  ['IN', 'PRP$', 'NN', 'TO', 'VB', 'TO', 'VB', 'PRP', 'DT', 'DT', 'NN', 'JJ'],
#  ['WRB',
#   'VB',
#   'PRP',
#   'RB',
#   'VB',
#   'PRP',
#   'NN',
#   'NN',
#   'VBP',
#   'VBP',
#   'DT',
#   'NN',
#   'NN'],
#  ['IN',
#   'VBN',
#   'VBZ',
#   'RB',
#   'VB',
#   'RP',
#   'IN',
#   'NN',
#   'NN',
#   'NN',
#   'IN',
#   'RB',
#   'PRP$',
#   'NN',
#   'RB',
#   'NN',
#   'JJ',
#   'VBD',
#   'IN',
#   'IN',
#   'NNS'],
#  ['WRB', 'IN', 'PRP', 'VBP', 'JJ', 'NN'],
#  ['NN', 'DT', 'JJ', 'NN', 'VBP', 'IN', 'IN', 'DT', 'JJ', 'JJ', 'NN'],
#  ['NN',
#   'PRP',
#   'VBP',
#   'JJ',
#   'VBP',
#   'VBG',
#   'IN',
#   'NN',
#   'NN',
#   'TO',
#   'PRP',
#   'PRP',
#   'VBP',
#   'VBG',
#   'NN',
#   'NN',
#   'NN'],
#  ['VB',
#   'PRP',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   'NN',
#   'RB',
#   'RB',
#   'MD',
#   'RB',
#   'VB',
#   'IN',
#   'JJ',
#   'NN',
#   'MD',
#   'VB',
#   'VB',
#   'RB',
#   'VB',
#   'PRP',
#   'RB'],
#  ['NNS', 'VBP', 'VBZ', 'RB', 'DT', 'NN', 'TO', 'VB', 'JJ', 'NN', 'IN', 'JJ'],
#  ['NNS',
#   'NN',
#   'CC',
#   'PRP',
#   'VBP',
#   'RB',
#   'VB',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'PRP',
#   'RB',
#   'VB',
#   'PRP',
#   'VBZ',
#   'JJ',
#   'VBN',
#   'NN'],
#  ['VBG', 'CD', 'JJ', 'NN', 'VBZ', 'NN', 'RBR', 'IN', 'VBG', 'NN', 'NN'],
#  ['NN', 'VBG', 'VB', 'PRP', 'PRP', 'VBD'],
#  ['VB',
#   'RP',
#   'PRP$',
#   'NN',
#   'NN',
#   'RB',
#   'IN',
#   'PDT',
#   'DT',
#   'JJ',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NN'],
#  ['WP',
#   'VB',
#   'TO',
#   'PRP',
#   'VBN',
#   'VBD',
#   'IN',
#   'PRP',
#   'VBD',
#   'NN',
#   'CC',
#   'VBD',
#   'TO',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'NN'],
#  ['IN', 'DT', 'NN', 'NN', 'NN', 'IN', 'NN', 'RB'],
#  ['PRP', 'VBP', 'VBG', 'NN', 'VBD', 'PRP', 'VBG', 'RP', 'IN', 'RB'],
#  ['DT', 'NN', 'VB', 'JJ', 'IN', 'DT', 'NN', 'NN', 'VBP'],
#  ['DT', 'VBD', 'RP', 'VB', 'PRP', 'VB'],
#  ['NN', 'VBP', 'DT', 'NN', 'VBP', 'JJ', 'NN', 'IN', 'NN'],
#  ['VBD',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'CC',
#   'VB',
#   'VBP',
#   'RB',
#   'RB',
#   'JJR',
#   'WDT',
#   'VBZ',
#   'RB',
#   'PRP$',
#   'JJ'],
#  ['NN', 'NN', 'IN', 'DT', 'NN', 'DT', 'VBZ', 'WRB', 'DT', 'NN', 'VBD'],
#  ['JJ', 'VBD', 'DT', 'NN', 'NN', 'VBP', 'RB', 'VB', 'IN', 'NN'],
#  ['PRP',
#   'RB',
#   'VBD',
#   'PRP',
#   'WDT',
#   'VBD',
#   'IN',
#   'JJ',
#   'DT',
#   'DT',
#   'NNS',
#   'MD',
#   'VB',
#   'JJ',
#   'NN',
#   'NN',
#   'NN'],
#  ['NN',
#   'VBP',
#   'DT',
#   'JJ',
#   'NN',
#   'CC',
#   'NN',
#   'VBP',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   'JJ',
#   'VBP',
#   'NN',
#   'CC',
#   'VBP',
#   'NN'],
#  ['VBG',
#   'IN',
#   'JJ',
#   'NN',
#   'VBZ',
#   'RB',
#   'JJ',
#   'JJ',
#   'NN',
#   'NN',
#   'VBP',
#   'DT',
#   'NN',
#   'VBD',
#   'DT',
#   'NN'],
#  ['NN',
#   'NN',
#   'VBZ',
#   'DT',
#   'JJ',
#   'JJ',
#   'NN',
#   'NN',
#   'PRP',
#   'VBP',
#   'JJ',
#   'JJ',
#   'NN'],
#  ['DT', 'NN', 'VBP', 'RB', 'VB', 'DT', 'TO', 'PRP', 'VB'],
#  ['DT',
#   'JJ',
#   'DT',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   'RB',
#   'IN',
#   'NN',
#   'MD',
#   'VB',
#   'CC',
#   'DT',
#   'VBZ',
#   'JJ',
#   'NNS',
#   'VBP'],
#  ['NN', 'VBD', 'RB', 'VB', 'NN', 'DT', 'FW', 'PRP', 'RB', 'VBD'],
#  ['DT',
#   'DT',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   'IN',
#   'NN',
#   'CC',
#   'JJ',
#   'NN',
#   'VBD',
#   'NNS',
#   'VBD',
#   'IN',
#   'IN'],
#  ['NN', 'MD', 'VB', 'IN', 'DT', 'JJ', 'IN', 'NN', 'IN', 'PRP$', 'NN', 'JJ'],
#  ['VBN',
#   'NN',
#   'JJ',
#   'JJ',
#   'NN',
#   'TO',
#   'VB',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   'VB',
#   'JJ'],
#  ['DT',
#   'NN',
#   'NN',
#   'NN',
#   'VBP',
#   'PRP',
#   'VBZ',
#   'JJ',
#   'TO',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   'PRP',
#   'PRP$',
#   'NN',
#   'IN',
#   'NN',
#   'VBG',
#   'IN',
#   'VBG',
#   'JJ',
#   'IN',
#   'IN',
#   'NN'],
#  ['VBP', 'JJ', 'JJ', 'NN', 'NN'],
#  ['DT',
#   'NN',
#   'VB',
#   'VBG',
#   'NN',
#   'MD',
#   'RB',
#   'VB',
#   'PRP',
#   'IN',
#   'NN',
#   'NN',
#   'NN'],
#  ['DT',
#   'NN',
#   'NN',
#   'DT',
#   'NN',
#   'VB',
#   'VBG',
#   'DT',
#   'JJS',
#   'VBG',
#   'JJ',
#   'NN',
#   'IN',
#   'NN'],
#  ['DT',
#   'RB',
#   'VBG',
#   'NN',
#   'CC',
#   'VBG',
#   'DT',
#   'NN',
#   'CC',
#   'NN',
#   'NN',
#   'UH',
#   'NN',
#   'VB',
#   'JJ',
#   'JJ',
#   'CC',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN'],
#  ['NN',
#   'NNS',
#   'VBP',
#   'NN',
#   'IN',
#   'PRP$',
#   'JJ',
#   'NN',
#   'PRP$',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'WRB',
#   'NN',
#   'VBD',
#   'IN',
#   'NN',
#   'PRP',
#   'VBD',
#   'VBN',
#   'IN',
#   'NN'],
#  ['IN', 'PRP', 'VBD', 'JJ', 'IN', 'PRP$', 'NN', 'JJ', 'NN', 'WDT', 'NN', 'NN'],
#  ['PRP', 'DT', 'MD', 'MD', 'MD', 'IN', 'PRP', 'VBD'],
#  ['JJ', 'NN', 'NN', 'IN', 'JJ', 'NN', 'WDT', 'NN', 'NN', 'RP'],
#  ['VBN', 'TO', 'VB', 'DT', 'NN', 'RP'],
#  ['RB',
#   'RB',
#   'VB',
#   'IN',
#   'NN',
#   'VBP',
#   'PRP$',
#   'JJ',
#   'NN',
#   'JJ',
#   'NN',
#   'PRP',
#   'VBP',
#   'JJ',
#   'RB',
#   'IN',
#   'NN'],
#  ['RB',
#   'PRP',
#   'VBP',
#   'PRP',
#   'VBP',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   'VBP',
#   'DT',
#   'NN',
#   'NN',
#   'MD'],
#  ['NN',
#   'NN',
#   'VBP',
#   'VBG',
#   'NN',
#   'IN',
#   'NN',
#   'CC',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'NN',
#   'NN',
#   'JJ',
#   'NN',
#   'IN',
#   'JJ',
#   'JJ',
#   'NN',
#   'NN'],
#  ['DT', 'VBZ', 'RB', 'JJ', 'PRP', 'VBZ', 'JJ', 'NN', 'VBP', 'VBG', 'DT', 'NN'],
#  ['NN',
#   'MD',
#   'NN',
#   'DT',
#   'PRP',
#   'RB',
#   'VBD',
#   'PRP',
#   'MD',
#   'RB',
#   'VB',
#   'IN',
#   'PRP',
#   'VBG',
#   'IN',
#   'DT',
#   'JJ',
#   'WRB',
#   'VBP',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN'],
#  ['VBG', 'JJ', 'VBZ', 'RB', 'DT', 'NN', 'TO', 'VB', 'DT', 'PRP'],
#  ['JJ', 'NN', 'NN', 'NN', 'JJ', 'NN', 'NN'],
#  ['VB',
#   'VB',
#   'JJ',
#   'NN',
#   'VBN',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   'VBD',
#   'JJ',
#   'NN',
#   'JJ',
#   'NNS',
#   'VBP',
#   'DT',
#   'NN'],
#  ['NN', 'WRB', 'JJ', 'VBN', 'IN', 'DT', 'NN', 'CC', 'RB', 'WRB', 'PRP', 'VBN'],
#  ['IN',
#   'NNS',
#   'VBP',
#   'RB',
#   'VB',
#   'PRP$',
#   'NN',
#   'VBD',
#   'IN',
#   'TO',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'NN',
#   'VBP',
#   'RB',
#   'VBN',
#   'VBN',
#   'PRP',
#   'RP',
#   'JJ',
#   'NN',
#   'NN',
#   'IN'],
#  ['VBZ', 'RB', 'JJ', 'CC', 'PRP', 'RB', 'VBD', 'NNS', 'IN', 'PRP', 'DT', 'NN'],
#  ['IN',
#   'DT',
#   'NN',
#   'VBZ',
#   'RP',
#   'DT',
#   'VBG',
#   'DT',
#   'NNS',
#   'MD',
#   'MD',
#   'VB',
#   'NN',
#   'NN'],
#  ['WP',
#   'VBP',
#   'TO',
#   'VB',
#   'RB',
#   'RB',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'RB',
#   'VBZ',
#   'RB',
#   'CC',
#   'VB'],
#  ['JJ',
#   'VBP',
#   'NN',
#   'VBP',
#   'DT',
#   'NN',
#   'IN',
#   'PRP$',
#   'NN',
#   'VB',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   'PRP',
#   'VBP'],
#  ['IN',
#   'PRP',
#   'VBD',
#   'RP',
#   'DT',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   'PRP',
#   'VBP',
#   'JJ',
#   'CC',
#   'DT',
#   'NN'],
#  ['MD',
#   'VB',
#   'RB',
#   'VB',
#   'DT',
#   'NN',
#   'NN',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'MD',
#   'TO',
#   'VB',
#   'IN',
#   'PRP',
#   'VBZ',
#   'CD'],
#  ['VB',
#   'VBG',
#   'VBN',
#   'TO',
#   'VB',
#   'PRP$',
#   'IN',
#   'NN',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   'PRP',
#   'VBZ',
#   'IN',
#   'PRP',
#   'VBP',
#   'DT',
#   'NN',
#   'WP',
#   'VBD',
#   'NN',
#   'IN',
#   'IN',
#   'NN',
#   'NN'],
#  ['RB',
#   'RB',
#   'JJ',
#   'NNS',
#   'VBP',
#   'PRP',
#   'VB',
#   'JJ',
#   'NN',
#   'PRP',
#   'RB',
#   'VB',
#   'JJ',
#   'IN',
#   'NN',
#   'PRP',
#   'VBP',
#   'PRP$',
#   'NN'],
#  ['UH',
#   'NN',
#   'PRP',
#   'VBP',
#   'PRP',
#   'RP',
#   'DT',
#   'RB',
#   'NN',
#   'WRB',
#   'DT',
#   'NN',
#   'DT',
#   'NN',
#   'IN'],
#  ['PRP',
#   'VBP',
#   'RB',
#   'DT',
#   'NN',
#   'IN',
#   'PRP',
#   'VBP',
#   'TO',
#   'DT',
#   'NN',
#   'DT',
#   'DT',
#   'NN'],
#  ['NN',
#   'DT',
#   'NN',
#   'VBD',
#   'VBG',
#   'DT',
#   'NN',
#   'IN',
#   'IN',
#   'PRP',
#   'PRP$',
#   'JJ',
#   'RB',
#   'VBD',
#   'DT',
#   'JJ',
#   'PRP$',
#   'NN'],
#  ['VB',
#   'RP',
#   'VB',
#   'IN',
#   'VBG',
#   'PRP',
#   'RB',
#   'RP',
#   'NN',
#   'RB',
#   'WRB',
#   'NN',
#   'VBP',
#   'IN',
#   'PRP',
#   'VBP',
#   'RB',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'WP',
#   'IN',
#   'VBD',
#   'IN',
#   'NN'],
#  ['TO', 'TO', 'DT', 'NN', 'NN', 'NN', 'VBD', 'JJ', 'NN', 'NN', 'VBZ', 'NN'],
#  ['RB',
#   'PRP',
#   'VBZ',
#   'PRP$',
#   'JJ',
#   'NN',
#   'JJ',
#   'NN',
#   'PRP$',
#   'JJ',
#   'NN',
#   'VBZ',
#   'JJ',
#   'JJ',
#   'VBP',
#   'VBG',
#   'IN',
#   'IN',
#   'PRP',
#   'VB'],
#  ['IN', 'JJ', 'NN', 'IN', 'NN', 'DT', 'VBZ', 'RB', 'JJ', 'TO', 'PRP'],
#  ['DT',
#   'VBZ',
#   'WRB',
#   'JJ',
#   'VBP',
#   'PRP$',
#   'JJ',
#   'NN',
#   'IN',
#   'VBG',
#   'JJ',
#   'NN',
#   'NNS',
#   'NN'],
#  ['VB', 'RB', 'VB', 'NN', 'IN', 'NN', 'TO', 'VB', 'NN', 'IN'],
#  ['VBN',
#   'IN',
#   'NN',
#   'JJ',
#   'NN',
#   'NN',
#   'DT',
#   'VBZ',
#   'RB',
#   'DT',
#   'JJ',
#   'NN',
#   'JJ'],
#  ['DT',
#   'NN',
#   'NN',
#   'VBZ',
#   'DT',
#   'PRP',
#   'VBP',
#   'JJ',
#   'JJR',
#   'WRB',
#   'NN',
#   'NN',
#   'VBP',
#   'PRP'],
#  ['NN',
#   'PRP',
#   'VBP',
#   'VB',
#   'NN',
#   'NN',
#   'VBP',
#   'JJ',
#   'DT',
#   'NN',
#   'VBZ',
#   'DT',
#   'JJ',
#   'WRB',
#   'JJ',
#   'NN',
#   'PRP',
#   'VBD',
#   'PRP',
#   'VB',
#   'PRP$',
#   'NN',
#   'IN',
#   'JJ',
#   'JJ',
#   'NN',
#   'PRP'],
#  ['JJ', 'NN', 'NN', 'RB', 'VB', 'PRP', 'IN', 'DT', 'NN', 'IN', 'IN', 'NN'],
#  ['NN', 'TO', 'VB', 'IN', 'RB', 'JJ', 'NN'],
#  ['NN',
#   'NN',
#   'IN',
#   'NN',
#   'CC',
#   'VBG',
#   'NN',
#   'DT',
#   'NN',
#   'CC',
#   'PRP',
#   'VBP',
#   'MD',
#   'RB',
#   'RB',
#   'VB',
#   'RP'],
#  ['PRP', 'VBP', 'DT', 'NNS', 'RBR', 'RB', 'NN', 'NN', 'JJ', 'DT', 'NN'],
#  ['DT',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'JJ',
#   'NN',
#   'VBZ',
#   'IN',
#   'VBG',
#   'DT',
#   'JJ',
#   'NN',
#   'VBG',
#   'IN',
#   'PRP',
#   'IN',
#   'EX',
#   'JJ'],
#  ['JJ', 'NN', 'NN', 'PRP', 'WDT', 'VBZ', 'DT', 'NN'],
#  ['NN', 'NN', 'VBZ', 'RB', 'JJ', 'JJ', 'VBG', 'NN', 'IN', 'NN', 'NN'],
#  ['JJ', 'NN', 'VBD', 'DT', 'VB', 'VBN', 'PRP', 'VBP', 'PDT', 'DT', 'NN', 'DT'],
#  ['NN', 'VBG', 'NN', 'MD', 'PRP', 'VB'],
#  ['NN', 'NN'],
#  ['VBN',
#   'RP',
#   'JJ',
#   'NN',
#   'PRP',
#   'VBP',
#   'IN',
#   'NN',
#   'NN',
#   'VBP',
#   'JJ',
#   'NN',
#   'PRP',
#   'VBP',
#   'JJ',
#   'NNS',
#   'VBP',
#   'RB',
#   'RB'],
#  ['MD', 'VBG', 'VB', 'NN', 'NN'],
#  ['JJ', 'NN', 'NN', 'RB', 'VBZ', 'NN'],
#  ['NN',
#   'VBD',
#   'TO',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   'MD',
#   'VB',
#   'RB',
#   'CD',
#   'NN'],
#  ['JJ',
#   'VBP',
#   'RB',
#   'NN',
#   'IN',
#   'NN',
#   'CC',
#   'JJ',
#   'NN',
#   'VBD',
#   'JJ',
#   'JJ',
#   'NNS',
#   'VBP'],
#  ['NN', 'VBD', 'DT', 'NN', 'VBP', 'IN', 'DT', 'NN', 'NN', 'IN', 'NN', 'NN'],
#  ['NN',
#   'RB',
#   'JJ',
#   'NN',
#   'NN',
#   'WDT',
#   'VBZ',
#   'DT',
#   'JJS',
#   'NN',
#   'NN',
#   'RB',
#   'RB',
#   'VBN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'TO',
#   'IN',
#   'NN'],
#  ['NN',
#   'NN',
#   'VBP',
#   'JJ',
#   'NNS',
#   'DT',
#   'VBZ',
#   'WRB',
#   'EX',
#   'VBZ',
#   'JJ',
#   'NNS',
#   'CC',
#   'NN'],
#  ['WRB', 'MD', 'VB', 'VB', 'DT', 'TO', 'PRP', 'VB', 'NN'],
#  ['DT',
#   'VBN',
#   'NN',
#   'IN',
#   'IN',
#   'NN',
#   'MD',
#   'VB',
#   'PRP$',
#   'NN',
#   'NN',
#   'IN',
#   'PRP',
#   'VBD'],
#  ['VB', 'NN', 'NN', 'NN', 'JJ', 'RB', 'NN'],
#  ['JJ', 'NN', 'IN', 'JJ', 'NN', 'CC', 'NN'],
#  ['IN',
#   'VBP',
#   'JJ',
#   'NN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'VBZ',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'VBP'],
#  ['NN', 'VBD', 'JJ', 'NN'],
#  ['DT',
#   'JJ',
#   'NN',
#   'VBZ',
#   'VBG',
#   'DT',
#   'NN',
#   'IN',
#   'IN',
#   'PRP',
#   'VBP',
#   'RB',
#   'TO',
#   'VB',
#   'JJ',
#   'NN'],
#  ['RB',
#   'JJ',
#   'IN',
#   'CC',
#   'IN',
#   'JJ',
#   'VBP',
#   'JJ',
#   'NN',
#   'RB',
#   'JJ',
#   'VBZ',
#   'IN',
#   'JJ',
#   'NN'],
#  ['CC',
#   'WP',
#   'IN',
#   'PRP',
#   'RB',
#   'VBZ',
#   'VB',
#   'DT',
#   'RB',
#   'NN',
#   'IN',
#   'PRP',
#   'PRP',
#   'IN',
#   'MD',
#   'VB',
#   'JJ'],
#  ['NN',
#   'MD',
#   'RB',
#   'VB',
#   'PRP$',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'WRB',
#   'NN',
#   'VBP',
#   'NN'],
#  ['NN',
#   'VBP',
#   'VBN',
#   'IN',
#   'NN',
#   'VBG',
#   'JJ',
#   'VBP',
#   'JJ',
#   'JJ',
#   'NN',
#   'PRP',
#   'JJ',
#   'IN',
#   'JJ',
#   'JJ',
#   'NN',
#   'CC',
#   'JJ',
#   'NN'],
#  ['VB', 'PRP$', 'NNS', 'MD', 'RB', 'VB', 'NNS', 'TO', 'VB', 'NN'],
#  ['VB', 'IN', 'PRP', 'VBP'],
#  ['NN',
#   'NN',
#   'NN',
#   'NN',
#   'DT',
#   'JJ',
#   'NN',
#   'RB',
#   'RB',
#   'IN',
#   'DT',
#   'NN',
#   'PRP',
#   'VBZ',
#   'CC',
#   'IN',
#   'RB',
#   'VBN',
#   'IN',
#   'NN',
#   'NN'],
#  ['NN', 'VBG', 'NN', 'CC', 'NN', 'VBG', 'NN'],
#  ['NN',
#   'VBP',
#   'RB',
#   'VBN',
#   'DT',
#   'NN',
#   'RB',
#   'VBN',
#   'IN',
#   'PRP',
#   'VBP',
#   'IN',
#   'NN',
#   'VBP',
#   'VBN',
#   'IN',
#   'NN'],
#  ['NN',
#   'NN',
#   'VBG',
#   'NN',
#   'CC',
#   'VB',
#   'JJ',
#   'RB',
#   'VB',
#   'JJ',
#   'NN',
#   'TO',
#   'VB',
#   'DT',
#   'CD',
#   'NN'],
#  ['IN', 'JJS', 'JJ', 'VBP', 'RB', 'DT', 'NN', 'NN'],
#  ['NNS',
#   'RB',
#   'VBG',
#   'PRP',
#   'WP',
#   'VBZ',
#   'VBP',
#   'JJ',
#   'IN',
#   'PRP',
#   'DT',
#   'JJ',
#   'NN',
#   'NN',
#   'NN'],
#  ['NN',
#   'VBZ',
#   'DT',
#   'NN',
#   'CC',
#   'DT',
#   'NN',
#   'CC',
#   'IN',
#   'JJS',
#   'PRP',
#   'VBZ',
#   'RB',
#   'DT',
#   'NN',
#   'IN',
#   'PRP$',
#   'NN',
#   'NN',
#   'NN'],
#  ['NN', 'NN', 'IN', 'JJ', 'NN', 'NN', 'NN', 'WDT', 'VBP', 'VBZ', 'NN', 'IN'],
#  ['NN',
#   'VBP',
#   'VBN',
#   'JJ',
#   'IN',
#   'PRP',
#   'VBD',
#   'VB',
#   'JJ',
#   'CC',
#   'VB',
#   'TO',
#   'VB',
#   'PRP'],
#  ['VB', 'VBG', 'JJ', 'NN', 'IN', 'PRP$', 'NN'],
#  ['PRP', 'VBP', 'RB', 'VB', 'DT', 'NN'],
#  ['IN',
#   'TO',
#   'VB',
#   'MD',
#   'VB',
#   'VBN',
#   'PRP',
#   'DT',
#   'IN',
#   'JJ',
#   'NN',
#   'IN',
#   'NN'],
#  ['NN',
#   'VBP',
#   'IN',
#   'NN',
#   'NNS',
#   'VBD',
#   'PRP',
#   'VBP',
#   'VB',
#   'RB',
#   'VB',
#   'DT',
#   'NN',
#   'CC',
#   'VB',
#   'RP',
#   'NN'],
#  ['NN', 'DT', 'JJ', 'IN', 'PRP$', 'JJ', 'JJ', 'NN'],
#  ['NN',
#   'NN',
#   'WRB',
#   'NN',
#   'VBP',
#   'PRP',
#   'PRP',
#   'VBP',
#   'VBG',
#   'PRP',
#   'VB',
#   'VB',
#   'VB',
#   'RB',
#   'VB',
#   'PRP$',
#   'NN',
#   'TO',
#   'VB',
#   'PRP',
#   'DT',
#   'VBD'],
#  ['VB', 'RP', 'NN', 'JJ', 'NN', 'IN', 'NN', 'IN', 'JJ', 'NN', 'NN'],
#  ['WRB', 'NN', 'VBD', 'IN', 'DT', 'NN', 'PRP', 'IN', 'DT', 'IN', 'DT', 'NN'],
#  ['NN', 'DT', 'VBZ', 'JJ', 'NN', 'VBN', 'PRP$', 'NN'],
#  ['IN',
#   'JJ',
#   'NN',
#   'NN',
#   'VBZ',
#   'VBN',
#   'IN',
#   'JJ',
#   'NNS',
#   'IN',
#   'PRP',
#   'DT',
#   'JJ',
#   'NN',
#   'VBZ',
#   'RB',
#   'RB'],
#  ['DT', 'NN', 'VBP', 'RB', 'VB', 'PRP', 'RB', 'VBP', 'DT', 'NN'],
#  ['PRP',
#   'VBD',
#   'DT',
#   'NN',
#   'IN',
#   'PRP',
#   'TO',
#   'VB',
#   'PRP',
#   'CC',
#   'JJ',
#   'VBP',
#   'VBG',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'IN',
#   'NN',
#   'JJ',
#   'NN',
#   'NN'],
#  ['VB',
#   'JJ',
#   'NN',
#   'WDT',
#   'MD',
#   'VB',
#   'VBN',
#   'IN',
#   'IN',
#   'NN',
#   'NNS',
#   'EX',
#   'VBZ',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'VBZ',
#   'DT',
#   'NN'],
#  ['NN', 'FW', 'NN', 'PRP', 'VBP', 'VB'],
#  ['NN',
#   'VBZ',
#   'JJ',
#   'JJ',
#   'NN',
#   'NN',
#   'VBP',
#   'JJ',
#   'WRB',
#   'TO',
#   'VB',
#   'VBN',
#   'DT',
#   'VBZ',
#   'DT',
#   'NN',
#   'VBP'],
#  ['NN',
#   'MD',
#   'RB',
#   'VB',
#   'CC',
#   'VB',
#   'WRB',
#   'TO',
#   'VB',
#   'JJ',
#   'NN',
#   'NN',
#   'TO',
#   'DT',
#   'NN',
#   'WDT',
#   'MD',
#   'VB',
#   'DT'],
#  ['NN', 'NN', 'VBP', 'JJ', 'NN'],
#  ['RB', 'PRP', 'VBP', 'JJ', 'DT', 'NN', 'VBZ', 'PRP', 'TO', 'VB', 'JJ'],
#  ['IN', 'NN', 'IN'],
#  ['NN',
#   'IN',
#   'NN',
#   'IN',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'VBD',
#   'IN',
#   'NN',
#   'NN',
#   'DT',
#   'NN',
#   'IN',
#   'JJ',
#   'NN'],
#  ['RB',
#   'IN',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'JJ',
#   'NN',
#   'PRP',
#   'RB',
#   'RB',
#   'DT',
#   'NN',
#   'MD',
#   'VB',
#   'PRP',
#   'VB',
#   'JJ',
#   'NN',
#   'NN',
#   'PRP'],
#  ['NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'IN',
#   'NN',
#   'CC',
#   'DT',
#   'NN',
#   'NN',
#   'PRP',
#   'VBP',
#   'IN',
#   'DT',
#   'NN',
#   'NN'],
#  ['NNS',
#   'VBP',
#   'RB',
#   'VB',
#   'TO',
#   'VB',
#   'NN',
#   'IN',
#   'PRP$',
#   'IN',
#   'IN',
#   'JJ',
#   'VBP',
#   'IN',
#   'NN',
#   'VBP',
#   'VBG',
#   'PRP$',
#   'JJ',
#   'WP',
#   'VBD'],
#  ['CD', 'IN', 'PRP$', 'NN', 'IN', 'DT', 'NN', 'VB', 'IN', 'PRP', 'VBP', 'RB'],
#  ['IN',
#   'DT',
#   'NN',
#   'RB',
#   'VBG',
#   'RB',
#   'PRP',
#   'VB',
#   'CC',
#   'RB',
#   'DT',
#   'NN',
#   'NN'],
#  ['DT', 'JJ', 'NN', 'VBG', 'PRP', 'VBP', 'CC', 'NN', 'NN', 'IN'],
#  ['MD', 'RB', 'VB', 'IN', 'DT', 'NN', 'WDT', 'NN', 'VBD', 'IN', 'PRP'],
#  ['NN',
#   'NN',
#   'VBP',
#   'IN',
#   'NN',
#   'NN',
#   'WDT',
#   'MD',
#   'RB',
#   'VB',
#   'DT',
#   'JJ',
#   'NN'],
#  ['IN',
#   'JJ',
#   'NN',
#   'MD',
#   'DT',
#   'NN',
#   'VB',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'PRP',
#   'IN',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'RP',
#   'JJ',
#   'JJ',
#   'NN'],
#  ['PRP$',
#   'NN',
#   'VBD',
#   'PRP',
#   'NN',
#   'VBZ',
#   'IN',
#   'PRP$',
#   'NN',
#   'PRP',
#   'VBD',
#   'NN',
#   'VBZ',
#   'VBG',
#   'CC',
#   'PRP',
#   'VB',
#   'PRP$',
#   'NN',
#   'NN'],
#  ['NN',
#   'VBP',
#   'JJ',
#   'CC',
#   'JJ',
#   'NN',
#   'VB',
#   'PRP$',
#   'NN',
#   'IN',
#   'NN',
#   'VBN',
#   'VBD',
#   'PRP',
#   'NN',
#   'IN',
#   'NN',
#   'NN'],
#  ['NN', 'NN', 'VB', 'VBG', 'TO', 'DT', 'IN', 'JJ', 'NN'],
#  ['UH', 'UH', 'NN', 'WDT', 'NN'],
#  ['JJ',
#   'NN',
#   'RB',
#   'VBD',
#   'PRP$',
#   'JJ',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'MD',
#   'VB'],
#  ['JJ',
#   'JJ',
#   'NN',
#   'NN',
#   'IN',
#   'JJ',
#   'NN',
#   'NN',
#   'VBP',
#   'NN',
#   'DT',
#   'NN',
#   'CC',
#   'VBZ',
#   'NN',
#   'PRP',
#   'VBZ',
#   'DT',
#   'NN'],
#  ['NN',
#   'WP',
#   'NN',
#   'RB',
#   'VBP',
#   'CD',
#   'NN',
#   'IN',
#   'PRP$',
#   'VBG',
#   'JJ',
#   'JJ',
#   'NN'],
#  ['VBG', 'JJ', 'NN', 'NN'],
#  ['NN', 'VBP', 'VBG', 'DT', 'NN', 'IN', 'PRP', 'VBP', 'PRP', 'VBP'],
#  ['NN', 'RB', 'VBZ', 'DT', 'JJ', 'VBD', 'NN'],
#  ['MD',
#   'RB',
#   'VB',
#   'NN',
#   'IN',
#   'PRP',
#   'VBP',
#   'RB',
#   'VB',
#   'NNS',
#   'VB',
#   'CC',
#   'VB',
#   'PRP',
#   'VB'],
#  ['VB', 'NN', 'NN', 'NN', 'NN', 'NN', 'IN', 'NN', 'NN'],
#  ['NN', 'VBP', 'RB', 'JJ', 'NN', 'JJ', 'JJ', 'VB', 'NN', 'PRP', 'IN', 'NN'],
#  ['DT', 'NN', 'VBZ', 'JJ'],
#  ['PRP', 'VBP', 'RB', 'RB', 'VB', 'DT', 'NN', 'NN', 'RB', 'VB'],
#  ['IN', 'RB', 'JJ', 'VBP', 'DT', 'NN', 'PRP$', 'NN', 'RB', 'VB', 'DT', 'NN'],
#  ['JJ',
#   'VBP',
#   'IN',
#   'DT',
#   'NN',
#   'WDT',
#   'VBD',
#   'NN',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   'NN',
#   'NN',
#   'PRP',
#   'RB',
#   'VBZ',
#   'NN',
#   'IN',
#   'NN'],
#  ['NN',
#   'NN',
#   'NN',
#   'NN',
#   'VB',
#   'PRP',
#   'DT',
#   'RB',
#   'NN',
#   'VBP',
#   'NN',
#   'RB',
#   'JJ',
#   'NN',
#   'NN'],
#  ['NNS',
#   'IN',
#   'IN',
#   'PRP$',
#   'JJ',
#   'NN',
#   'IN',
#   'PRP$',
#   'NN',
#   'PRP',
#   'RB',
#   'VBD'],
#  ['MD',
#   'PRP',
#   'RB',
#   'VB',
#   'PRP',
#   'WRB',
#   'NN',
#   'VBP',
#   'RB',
#   'RB',
#   'JJ',
#   'CC',
#   'JJ',
#   'DT',
#   'RB',
#   'VBZ',
#   'IN'],
#  ['PRP', 'DT', 'VBP', 'IN', 'DT', 'JJ', 'NN', 'NN', 'VBP', 'VBG'],
#  ['NNS', 'NN'],
#  ['NN',
#   'NN',
#   'VBP',
#   'IN',
#   'PRP$',
#   'NN',
#   'NN',
#   'VBP',
#   'RB',
#   'VB',
#   'DT',
#   'JJ',
#   'VB',
#   'JJ',
#   'VB',
#   'DT',
#   'VBD',
#   'RP',
#   'JJ',
#   'NN',
#   'CD'],
#  ['DT', 'NN', 'NN', 'MD', 'VB', 'PRP'],
#  ['JJ', 'NN', 'NN', 'JJ', 'NN'],
#  ['NN',
#   'RB',
#   'VBZ',
#   'DT',
#   'NN',
#   'IN',
#   'TO',
#   'VB',
#   'IN',
#   'NN',
#   'NN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'NN'],
#  ['NN',
#   'VBP',
#   'VBG',
#   'NN',
#   'NN',
#   'NN',
#   'RB',
#   'VBP',
#   'JJ',
#   'NN',
#   'NN',
#   'MD',
#   'VB',
#   'DT',
#   'NN',
#   'RB',
#   'RBR',
#   'CC',
#   'RB'],
#  ['DT', 'NN', 'RB', 'JJ', 'RB', 'VBP', 'VB', 'PRP', 'VB', 'NN', 'IN', 'NN'],
#  ['DT', 'NN', 'RB', 'JJ', 'RB', 'VBP', 'NNS'],
#  ['NN',
#   'NN',
#   'VB',
#   'VBG',
#   'PRP',
#   'VBP',
#   'DT',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'VBP',
#   'IN',
#   'PRP',
#   'IN',
#   'PRP$',
#   'NN'],
#  ['TO', 'VB', 'VBZ', 'JJ', 'NN', 'PRP$', 'NN', 'DT', 'NN'],
#  ['NN', 'MD', 'VB', 'PRP$', 'NN', 'IN', 'DT', 'NN', 'NN'],
#  ['CC', 'IN', 'PRP', 'VBP', 'DT', 'PRP', 'VB', 'RP', 'RP', 'PRP$', 'NN'],
#  ['NN',
#   'TO',
#   'VB',
#   'NN',
#   'PRP',
#   'VBP',
#   'RB',
#   'JJ',
#   'IN',
#   'JJ',
#   'VBP',
#   'DT',
#   'NN'],
#  ['DT', 'NN', 'NN', 'VBP', 'DT', 'NN', 'NN', 'NN', 'VBZ', 'DT'],
#  ['NN', 'VB', 'PRP'],
#  ['NN', 'NN', 'PRP', 'VBG', 'PRP', 'JJ', 'JJ', 'NN', 'NN', 'JJ', 'NN', 'NN'],
#  ['IN', 'PRP$', 'NN', 'TO', 'VB', 'PRP$', 'NN', 'NN', 'NN'],
#  ['DT', 'JJ', 'VBZ', 'WRB', 'PRP', 'VBD', 'VB', 'IN', 'DT', 'NN', 'NN'],
#  ['VB',
#   'PRP$',
#   'JJ',
#   'NN',
#   'RB',
#   'VB',
#   'RB',
#   'VBP',
#   'VB',
#   'VB',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   'NN'],
#  ['PRP',
#   'JJ',
#   'JJ',
#   'VB',
#   'DT',
#   'PRP',
#   'MD',
#   'VB',
#   'IN',
#   'VBG',
#   'VBN',
#   'NN',
#   'PRP',
#   'WRB'],
#  ['WRB',
#   'DT',
#   'NN',
#   'VBG',
#   'PRP',
#   'PRP$',
#   'NN',
#   'VBZ',
#   'RB',
#   'RB',
#   'DT',
#   'RBS',
#   'JJ',
#   'DT'],
#  ['NN', 'RB', 'VB', 'DT', 'NN', 'IN', 'JJ', 'NN', 'PRP', 'VB'],
#  ['NN',
#   'IN',
#   'NN',
#   'VBP',
#   'PRP$',
#   'JJ',
#   'NN',
#   'VBG',
#   'VBG',
#   'PRP',
#   'VBD',
#   'IN',
#   'VBN',
#   'NN',
#   'NN',
#   'DT',
#   'NN',
#   'NN'],
#  ['NN',
#   'VBP',
#   'VBG',
#   'NN',
#   'PRP$',
#   'NN',
#   'NN',
#   'NN',
#   'PRP',
#   'VBG',
#   'VB',
#   'RB',
#   'IN',
#   'JJ',
#   'NN',
#   'PRP'],
#  ['NN', 'NN', 'NN', 'PRP', 'VBP', 'PRP'],
#  ['NN',
#   'MD',
#   'VB',
#   'DT',
#   'NN',
#   'PRP',
#   'VBP',
#   'JJ',
#   'IN',
#   'IN',
#   'IN',
#   'RB',
#   'DT',
#   'WRB',
#   'PRP',
#   'RB',
#   'VBG',
#   'IN'],
#  ['RB', 'CD', 'NN', 'TO', 'VB', 'IN', 'DT', 'NN', 'IN', 'DT', 'NN'],
#  ['VB', 'RB', 'VB', 'NN', 'IN', 'DT', 'JJ', 'NN', 'NN', 'NN'],
#  ['JJ', 'NN', 'NN', 'NN', 'NNS', 'VBP'],
#  ['JJ',
#   'VBG',
#   'IN',
#   'JJS',
#   'VB',
#   'MD',
#   'RB',
#   'VB',
#   'IN',
#   'PRP',
#   'VBP',
#   'PRP',
#   'VBP',
#   'VBD',
#   'JJ',
#   'NN',
#   'NN',
#   'NN'],
#  ['IN',
#   'JJ',
#   'JJR',
#   'NN',
#   'JJ',
#   'NN',
#   'CC',
#   'PRP',
#   'VBP',
#   'JJ',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   'DT',
#   'NN',
#   'JJ',
#   'NN'],
#  ['NN',
#   'NN',
#   'VBD',
#   'IN',
#   'JJ',
#   'NN',
#   'DT',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'VBD',
#   'VBP',
#   'RB',
#   'VB',
#   'PRP',
#   'RB',
#   'RB',
#   'VBN',
#   'VBN',
#   'VBD'],
#  ['NN',
#   'RB',
#   'JJ',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'DT',
#   'JJ',
#   'NN',
#   'VBZ',
#   'JJ',
#   'IN',
#   'PRP',
#   'JJ',
#   'RB',
#   'JJ',
#   'MD',
#   'CC',
#   'VB'],
#  ['PRP$', 'NN', 'RB', 'JJ', 'NN', 'VBP', 'NNS', 'VBP'],
#  ['IN',
#   'NN',
#   'VBZ',
#   'CD',
#   'DT',
#   'JJS',
#   'NN',
#   'NN',
#   'NN',
#   'VBD',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'IN',
#   'PRP',
#   'VBD',
#   'JJ',
#   'NN',
#   'VBP',
#   'VB',
#   'JJ',
#   'IN',
#   'DT',
#   'NN'],
#  ['NN',
#   'NN',
#   'VBP',
#   'RB',
#   'JJ',
#   'JJR',
#   'PRP',
#   'VBG',
#   'JJ',
#   'NN',
#   'VBP',
#   'IN',
#   'PRP',
#   'VBP',
#   'JJ',
#   'IN',
#   'DT'],
#  ['JJ',
#   'NN',
#   'VBZ',
#   'RP',
#   'IN',
#   'JJ',
#   'NN',
#   'IN',
#   'JJ',
#   'NN',
#   'VB',
#   'JJ',
#   'NN',
#   'PRP',
#   'VBG',
#   'IN',
#   'JJ',
#   'NN',
#   'IN',
#   'RB'],
#  ['EX',
#   'VBZ',
#   'DT',
#   'NN',
#   'DT',
#   'VBP',
#   'NN',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   'JJ',
#   'VB',
#   'JJ',
#   'DT',
#   'NN',
#   'VBZ',
#   'PRP$',
#   'NN',
#   'JJ',
#   'NN'],
#  ['NN', 'NN', 'WRB', 'NN', 'VBP', 'IN', 'PRP', 'VBP', 'VBN', 'NN'],
#  ['DT',
#   'NN',
#   'IN',
#   'RB',
#   'RB',
#   'VBG',
#   'PRP',
#   'DT',
#   'VBP',
#   'RB',
#   'VB',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN'],
#  ['IN', 'DT', 'NN', 'IN', 'NN', 'WDT', 'VBP', 'TO', 'VB', 'IN', 'DT', 'NN'],
#  ['PRP', 'VBZ', 'DT', 'PRP', 'NN', 'MD', 'RB'],
#  ['PRP',
#   'CC',
#   'VB',
#   'NN',
#   'IN',
#   'VBG',
#   'NN',
#   'IN',
#   'JJ',
#   'NN',
#   'NN',
#   'VBD',
#   'NN',
#   'NN',
#   'VB',
#   'IN',
#   'JJ',
#   'NN'],
#  ['NN',
#   'NN',
#   'PRP',
#   'VBP',
#   'RP',
#   'WRB',
#   'PRP',
#   'VB',
#   'VBN',
#   'RP',
#   'CC',
#   'IN',
#   'DT',
#   'NN',
#   'VBP',
#   'TO',
#   'NN',
#   'CC',
#   'DT',
#   'JJ',
#   'PRP',
#   'VBZ',
#   'DT',
#   'JJ',
#   'NN',
#   'NN'],
#  ['WRB', 'VB', 'PRP$', 'NN', 'VB', 'PRP', 'IN', 'PRP', 'DT', 'NN', 'PRP'],
#  ['DT', 'NN', 'IN', 'DT', 'JJ', 'NN', 'NN'],
#  ['JJ',
#   'NN',
#   'VBD',
#   'DT',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'PRP',
#   'CC',
#   'PRP$',
#   'NN'],
#  ['NN', 'VBD', 'RP', 'JJ', 'JJ', 'NN', 'NN'],
#  ['DT', 'NN', 'NN', 'NN'],
#  ['NN',
#   'VBD',
#   'VBD',
#   'PRP',
#   'IN',
#   'RB',
#   'CC',
#   'JJ',
#   'RB',
#   'VBD',
#   'VB',
#   'JJ',
#   'NN',
#   'NN',
#   'VBD',
#   'VBN',
#   'NN'],
#  ['WP', 'MD', 'VB', 'NN', 'PRP$', 'NN', 'NN', 'NN', 'NN'],
#  ['NN', 'NN', 'NN', 'RB', 'VBZ', 'NN'],
#  ['JJ',
#   'VBP',
#   'DT',
#   'NN',
#   'NN',
#   'VBG',
#   'VBN',
#   'JJ',
#   'WRB',
#   'PRP',
#   'VBD',
#   'VB',
#   'JJ',
#   'NN',
#   'PRP',
#   'VBP',
#   'RB',
#   'VBN',
#   'PRP'],
#  ['RB',
#   'VBZ',
#   'PRP$',
#   'JJ',
#   'NN',
#   'NN',
#   'VBP',
#   'PRP',
#   'VBZ',
#   'RB',
#   'JJ',
#   'PRP',
#   'RB',
#   'RB',
#   'VB',
#   'PRP',
#   'DT',
#   'JJ',
#   'PRP'],
#  ['NN', 'NN', 'DT', 'WP', 'JJ', 'NN', 'VBG', 'DT', 'NN', 'NN', 'NN', 'NN'],
#  ['VBZ', 'VBN', 'VBN', 'TO', 'VB', 'VBN', 'PRP', 'VBP', 'RB'],
#  ['CD', 'NN', 'NN', 'VBZ', 'DT', 'NN', 'NN'],
#  ['NNS',
#   'VBP',
#   'RB',
#   'VB',
#   'DT',
#   'NN',
#   'JJ',
#   'NN',
#   'VBZ',
#   'DT',
#   'JJ',
#   'NN',
#   'NN',
#   'IN',
#   'NN'],
#  ['VBN',
#   'VBZ',
#   'DT',
#   'NN',
#   'VBP',
#   'PRP',
#   'JJ',
#   'VBP',
#   'PRP',
#   'PRP',
#   'VBP',
#   'JJR',
#   'PRP$',
#   'NN',
#   'DT',
#   'NN'],
#  ['NN', 'VBZ', 'NN', 'NN', 'JJ', 'NN', 'NN'],
#  ['PRP', 'PRP', 'PRP', 'PRP', 'PRP', 'PRP', 'VBD'],
#  ['IN',
#   'JJ',
#   'NN',
#   'PRP',
#   'VBP',
#   'PRP',
#   'NN',
#   'IN',
#   'NN',
#   'PRP',
#   'VBP',
#   'PRP',
#   'NN',
#   'DT',
#   'IN',
#   'NN',
#   'PRP',
#   'VBP',
#   'VBN',
#   'VBN',
#   'DT',
#   'DT',
#   'PRP'],
#  ['NN',
#   'VBP',
#   'NN',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'DT',
#   'PRP',
#   'MD',
#   'RB',
#   'VB',
#   'RB',
#   'VB'],
#  ['NN',
#   'WRB',
#   'NN',
#   'NN',
#   'CC',
#   'VB',
#   'PRP',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'NN',
#   'VBP',
#   'VBG',
#   'TO',
#   'VB',
#   'VB',
#   'PRP',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'PRP$',
#   'NN'],
#  ['NN',
#   'JJ',
#   'NN',
#   'VBD',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'NN',
#   'VBD',
#   'IN',
#   'PRP$',
#   'NN',
#   'NN'],
#  ['DT', 'DT', 'VBD', 'RP', 'NN', 'DT', 'DT', 'NN', 'NN', 'NN'],
#  ['VB', 'PRP', 'IN', 'DT', 'NN', 'NN', 'NN'],
#  ['UH',
#   'PRP$',
#   'NN',
#   'NN',
#   'VBP',
#   'NN',
#   'NN',
#   'DT',
#   'PRP$',
#   'NN',
#   'IN',
#   'PRP'],
#  ['IN',
#   'JJ',
#   'NN',
#   'VBD',
#   'RB',
#   'JJ',
#   'VBD',
#   'DT',
#   'NN',
#   'NN',
#   'VBG',
#   'RP',
#   'NNS'],
#  ['PRP', 'VBZ', 'VBG', 'PRP', 'JJ', 'DT', 'NN', 'NN'],
#  ['PRP', 'VBP', 'JJ', 'NN', 'IN', 'NN', 'PRP', 'VBZ', 'NN', 'CD', 'NN', 'NN'],
#  ['VBD',
#   'VBP',
#   'JJ',
#   'CC',
#   'NN',
#   'VBP',
#   'JJ',
#   'CC',
#   'NN',
#   'VBP',
#   'JJ',
#   'PRP',
#   'VBP',
#   'DT',
#   'VBZ',
#   'JJ'],
#  ['VBG',
#   'IN',
#   'PRP$',
#   'NN',
#   'NN',
#   'VBD',
#   'JJ',
#   'NN',
#   'NN',
#   'TO',
#   'VB',
#   'IN',
#   'JJ',
#   'PRP'],
#  ['CC',
#   'DT',
#   'NN',
#   'IN',
#   'VB',
#   'DT',
#   'JJ',
#   'VB',
#   'DT',
#   'NN',
#   'PRP',
#   'VBP',
#   'RB',
#   'VBN'],
#  ['DT',
#   'NN',
#   'DT',
#   'JJ',
#   'NN',
#   'MD',
#   'RB',
#   'VB',
#   'NN',
#   'VBP',
#   'PDT',
#   'DT',
#   'NN'],
#  ['NN',
#   'VBP',
#   'RB',
#   'RB',
#   'JJ',
#   'JJ',
#   'FW',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'VBN',
#   'IN',
#   'NN'],
#  ['NN',
#   'IN',
#   'VBD',
#   'VBN',
#   'IN',
#   'DT',
#   'NN',
#   'PRP',
#   'VBZ',
#   'IN',
#   'IN',
#   'DT',
#   'NN',
#   'CC',
#   'PRP',
#   'RB',
#   'VBD',
#   'RBR',
#   'NN',
#   'IN',
#   'PRP',
#   'IN',
#   'NN',
#   'NN',
#   'IN',
#   'NN',
#   'NN'],
#  ['NN', 'VBZ', 'DT', 'NN', 'NN', 'NN'],
#  ['JJ', 'JJ', 'NN', 'JJ', 'NN', 'NN'],
#  ['NN', 'NN', 'NN', 'NN', 'VBZ', 'VBN', 'IN', 'NN', 'NN'],
#  ['PRP', 'MD', 'VB', 'PRP', 'JJ', 'NN', 'NN', 'VBP', 'DT', 'NN', 'IN'],
#  ['NN',
#   'MD',
#   'RB',
#   'VB',
#   'DT',
#   'IN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'DT',
#   'NN',
#   'NN',
#   'VBD',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'PRP$',
#   'NN'],
#  ['NN',
#   'NN',
#   'VB',
#   'TO',
#   'VB',
#   'IN',
#   'PRP',
#   'IN',
#   'PRP',
#   'VBP',
#   'DT',
#   'NN',
#   'CC',
#   'RB',
#   'VBD',
#   'DT',
#   'NN',
#   'IN',
#   'JJ',
#   'NN',
#   'WRB',
#   'NN',
#   'VBP',
#   'IN'],
#  ['CC',
#   'VBD',
#   'VBN',
#   'IN',
#   'JJ',
#   'NNPS',
#   'NN',
#   'NN',
#   'VBP',
#   'WP',
#   'PRP',
#   'VBP',
#   'VB',
#   'PRP',
#   'VB',
#   'RB',
#   'VB',
#   'PRP',
#   'VBP',
#   'IN',
#   'PRP',
#   'VBP',
#   'VBP',
#   'PRP',
#   'VBD'],
#  ['JJ', 'NN', 'DT', 'NN', 'NN', 'NN'],
#  ['PRP$', 'JJ', 'JJ', 'IN', 'NN', 'NN'],
#  ['WRB', 'NN', 'NN', 'VB', 'PRP', 'PRP$', 'NN', 'NN'],
#  ['JJ', 'NN', 'IN', 'PRP'],
#  ['RB', 'DT', 'NN', 'NN', 'IN', 'DT', 'PRP', 'JJ'],
#  ['NN', 'VBP', 'IN', 'IN', 'NN', 'VBG', 'TO', 'PRP', 'NN', 'NN'],
#  ['PRP',
#   'VBP',
#   'VB',
#   'VBG',
#   'TO',
#   'VB',
#   'IN',
#   'JJ',
#   'PRP',
#   'VBP',
#   'RB',
#   'VBN'],
#  ['NN', 'NN', 'PRP', 'RP', 'NN'],
#  ['NN', 'DT', 'NN', 'IN', 'JJS', 'NN', 'MD', 'VB', 'DT', 'JJ', 'NN'],
#  ['JJ', 'VB', 'IN', 'VBG', 'DT', 'NN', 'IN', 'NN', 'NN', 'NN', 'TO', 'VB'],
#  ['NN', 'PRP', 'VBZ', 'IN', 'JJ', 'NN'],
#  ['NN', 'NN', 'VBD', 'JJS', 'NN', 'NN'],
#  ['NN', 'NN', 'NN', 'IN', 'JJ', 'NN', 'IN', 'NN', 'NN'],
#  ['NN', 'WP', 'VBD', 'NN', 'VBD', 'DT', 'NN', 'VBD', 'JJ', 'MD', 'VB'],
#  ['NN', 'NN', 'NN', 'CC', 'RB', 'PRP', 'VBP', 'PRP', 'VB'],
#  ['PRP', 'NN', 'IN', 'PRP', 'VBZ', 'DT', 'JJ', 'NN', 'VBD'],
#  ['NN',
#   'MD',
#   'VB',
#   'IN',
#   'JJ',
#   'NN',
#   'NN',
#   'CC',
#   'MD',
#   'RB',
#   'RB',
#   'VB',
#   'NN',
#   'IN',
#   'PRP',
#   'VB'],
#  ['DT', 'VBZ', 'RB', 'JJ', 'JJ', 'VB', 'PRP', 'DT', 'VBP', 'RB'],
#  ['PRP',
#   'DT',
#   'VBP',
#   'IN',
#   'NN',
#   'VB',
#   'RB',
#   'VBN',
#   'TO',
#   'VB',
#   'VBN',
#   'PRP',
#   'DT',
#   'JJ',
#   'DT',
#   'NN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   'RB',
#   'RB'],
#  ['NN', 'MD', 'VB', 'TO', 'VB', 'IN', 'DT', 'NN'],
#  ['NNS',
#   'VBP',
#   'RB',
#   'VB',
#   'NN',
#   'NN',
#   'JJ',
#   'VBD',
#   'NN',
#   'WRB',
#   'NN',
#   'VBP',
#   'IN',
#   'DT',
#   'PRP$',
#   'NN',
#   'NN',
#   'JJ',
#   'NN',
#   'PRP',
#   'VBP',
#   'VBN',
#   'TO',
#   'VB',
#   'CC',
#   'VB',
#   'NN'],
#  ['IN',
#   'DT',
#   'NNS',
#   'IN',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   'NN',
#   'VBD',
#   'DT',
#   'DT',
#   'EX',
#   'CD',
#   'JJR',
#   'NN'],
#  ['RB',
#   'JJ',
#   'VBD',
#   'WP',
#   'JJ',
#   'VBP',
#   'NN',
#   'VB',
#   'PRP',
#   'RB',
#   'DT',
#   'VBZ',
#   'DT',
#   'JJ',
#   'NN',
#   'NN',
#   'MD',
#   'VB',
#   'TO',
#   'VB'],
#  ['VBN',
#   'NN',
#   'IN',
#   'PRP$',
#   'NN',
#   'NN',
#   'IN',
#   'NN',
#   'NN',
#   'NN',
#   'MD',
#   'RB',
#   'VB',
#   'PRP',
#   'IN',
#   'DT',
#   'MD'],
#  ['NN', 'RB', 'DT', 'NN', 'IN', 'NNS', 'VBP', 'PRP', 'VBP', 'RB', 'VB', 'NN'],
#  ['NN', 'VBP', 'JJ', 'NN', 'VBG', 'NN', 'NN', 'NN', 'IN', 'PRP', 'JJS'],
#  ['NN',
#   'DT',
#   'NN',
#   'CC',
#   'RB',
#   'PRP',
#   'VBP',
#   'IN',
#   'WRB',
#   'PRP',
#   'VBP',
#   'JJ',
#   'NN',
#   'PRP',
#   'VBP',
#   'VB',
#   'WRB',
#   'PRP',
#   'VBP',
#   'JJ',
#   'VB',
#   'PRP$',
#   'NN',
#   'VBZ',
#   'JJ'],
#  ['CD',
#   'IN',
#   'NN',
#   'VBZ',
#   'IN',
#   'NN',
#   'CC',
#   'PRP',
#   'PRP',
#   'CC',
#   'PRP',
#   'VBP',
#   'RB',
#   'JJ',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'RB'],
#  ['NN', 'VBP', 'VBG', 'RB', 'JJ', 'NN', 'NN'],
#  ['NNS', 'VBP', 'VBP', 'NN', 'RB', 'RB', 'IN', 'NN', 'NN'],
#  ['DT', 'VBZ', 'DT', 'JJ', 'NN', 'CC', 'VB', 'VB', 'WP', 'DT', 'NN', 'NN'],
#  ['RB', 'CC', 'VB', 'NN'],
#  ['DT',
#   'JJ',
#   'VBP',
#   'VBZ',
#   'JJ',
#   'NN',
#   'IN',
#   'IN',
#   'PRP$',
#   'NN',
#   'RB',
#   'JJ',
#   'VBP',
#   'PDT',
#   'IN',
#   'PRP',
#   'VBP',
#   'JJ',
#   'NN'],
#  ['NN', 'VBP', 'IN', 'TO', 'VB', 'JJ', 'NN', 'IN', 'VBZ', 'JJ', 'RB'],
#  ['NN', 'VBP', 'RB', 'JJ', 'NN', 'IN', 'IN'],
#  ['NN',
#   'VBZ',
#   'RB',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   'NN',
#   'PRP',
#   'VBG',
#   'VB',
#   'PRP',
#   'VBZ',
#   'WRB',
#   'JJ',
#   'NN',
#   'MD',
#   'VB',
#   'NNS',
#   'VBP',
#   'DT',
#   'VBG',
#   'JJ'],
#  ['VBD',
#   'DT',
#   'NN',
#   'NN',
#   'VBG',
#   'PRP',
#   'VBP',
#   'PRP',
#   'CC',
#   'JJ',
#   'NNS',
#   'VB',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   'PRP',
#   'JJ',
#   'CC',
#   'JJ',
#   'VBP',
#   'IN'],
#  ['NN', 'VBP', 'IN', 'JJ', 'CC', 'NN'],
#  ['NN',
#   'VBD',
#   'NNS',
#   'TO',
#   'CC',
#   'NN',
#   'IN',
#   'PRP$',
#   'NN',
#   'PRP',
#   'RB',
#   'VBD',
#   'PRP',
#   'NN',
#   'IN'],
#  ['JJ', 'VBD', 'WP', 'NN'],
#  ['DT',
#   'NN',
#   'RB',
#   'RB',
#   'VBP',
#   'RB',
#   'VB',
#   'DT',
#   'NN',
#   'NN',
#   'MD',
#   'VB',
#   'DT',
#   'NN',
#   'NN',
#   'NN',
#   'VBZ',
#   'VBN',
#   'NN'],
#  ['NN',
#   'NN',
#   'PRP',
#   'VBD',
#   'PRP',
#   'IN',
#   'VBN',
#   'TO',
#   'VB',
#   'NN',
#   'RB',
#   'VBP',
#   'NNS',
#   'IN'],
#  ['VBG', 'PRP', 'PRP$', 'NN', 'TO', 'VB', 'DT', 'NN', 'IN', 'DT', 'IN'],
#  ['JJ', 'NN', 'JJ', 'NN', 'DT', 'NNS', 'VBP', 'JJ', 'NN', 'MD', 'VB', 'PRP'],
#  ['NN', 'CC', 'NN', 'VBP', 'UH', 'JJ', 'JJ', 'NN', 'IN', 'JJ', 'NN'],
#  ['VBG', 'RP', 'DT', 'NN', 'NN', 'VBP', 'NN', 'NN', 'VBD', 'NNS'],
#  ['NN',
#   'VBG',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   'VBP',
#   'NN',
#   'JJ',
#   'NN',
#   'JJ',
#   'NN',
#   'RB'],
#  ['JJ',
#   'NN',
#   'NN',
#   'VBZ',
#   'RB',
#   'VB',
#   'IN',
#   'PRP',
#   'VBP',
#   'VB',
#   'PRP',
#   'MD',
#   'RB',
#   'VB',
#   'PRP',
#   'IN',
#   'NN',
#   'NN'],
#  ['RB',
#   'JJ',
#   'NN',
#   'PRP',
#   'VBZ',
#   'JJ',
#   'RB',
#   'VBP',
#   'IN',
#   'NN',
#   'JJ',
#   'NN',
#   'NN'],
#  ['PRP',
#   'DT',
#   'VBP',
#   'NN',
#   'VBP',
#   'JJ',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'NN',
#   'VBD',
#   'JJ',
#   'VBZ'],
#  ['NN',
#   'VBD',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   'IN',
#   'DT',
#   'NN',
#   'VBG',
#   'RB',
#   'DT',
#   'VBZ',
#   'RB',
#   'JJ',
#   'IN',
#   'NN',
#   'MD',
#   'RB',
#   'RB',
#   'VB',
#   'TO',
#   'PRP',
#   'IN',
#   'NN'],
#  ['NN',
#   'DT',
#   'RB',
#   'JJ',
#   'NN',
#   'NN',
#   'VBP',
#   'DT',
#   'NN',
#   'NN',
#   'NN',
#   'VBD',
#   'NN',
#   'RB',
#   'CC',
#   'VB'],
#  ['NNS',
#   'VBP',
#   'RB',
#   'RB',
#   'VB',
#   'NN',
#   'IN',
#   'DT',
#   'WDT',
#   'VBZ',
#   'JJ',
#   'NN',
#   'NN',
#   'NN'],
#  ['NN', 'VB', 'JJ', 'NN', 'IN', 'JJ', 'NN', 'WP', 'VBP', 'PRP', 'VB'],
#  ['JJ', 'VB', 'DT', 'NN', 'NN', 'NN', 'WRB', 'VBD', 'PRP', 'VB', 'IN'],
#  ['JJ', 'JJ', 'NN', 'VB', 'PRP$', 'NN', 'NN', 'VBZ', 'VBG', 'DT', 'NN'],
#  ['JJ', 'PRP$', 'JJ', 'JJ', 'NN', 'NNS', 'VBP', 'PRP', 'JJ', 'NN', 'NN', 'NN'],
#  ['NN',
#   'IN',
#   'NN',
#   'VBZ',
#   'JJ',
#   'DT',
#   'IN',
#   'PRP',
#   'VBP',
#   'VB',
#   'TO',
#   'VB',
#   'DT',
#   'IN',
#   'DT',
#   'NN',
#   'JJ',
#   'NN'],
#  ['IN',
#   'CD',
#   'IN',
#   'PRP',
#   'VBP',
#   'VBP',
#   'DT',
#   'IN',
#   'PRP$',
#   'NN',
#   'NN',
#   'MD',
#   'VB',
#   'PRP',
#   'IN',
#   'NN',
#   'NN',
#   'NN'],
#  ['NN', 'JJ', 'NN', 'IN', 'RB', 'VBN', 'MD', 'RB', 'VBD', 'VBD', 'PRP', 'JJR'],
#  ['NN',
#   'NN',
#   'TO',
#   'VB',
#   'NN',
#   'CC',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'VBP',
#   'VBG',
#   'NN',
#   'VBD',
#   'NN'],
#  ['IN',
#   'PRP$',
#   'NN',
#   'VBZ',
#   'RB',
#   'JJ',
#   'IN',
#   'NNS',
#   'WDT',
#   'VBZ',
#   'DT',
#   'JJ',
#   'IN',
#   'NN',
#   'NN',
#   'RB'],
#  ['VBG', 'NN', 'IN', 'JJ', 'VBP', 'NN', 'RB', 'RB'],
#  ['MD', 'VB', 'VBD', 'IN', 'DT', 'NNS'],
#  ['NN', 'NN', 'DT', 'NN', 'NN', 'NN'],
#  ['NN', 'PRP', 'VBZ', 'IN', 'DT', 'NN'],
#  ['VB', 'NN', 'RB', 'VB'],
#  ['MD',
#   'RB',
#   'VB',
#   'DT',
#   'NN',
#   'VBP',
#   'RB',
#   'VB',
#   'WP',
#   'JJ',
#   'VBP',
#   'IN',
#   'JJ',
#   'NN',
#   'NN'],
#  ['NN', 'VBP', 'IN', 'PRP$', 'NN', 'IN', 'DT', 'JJ', 'NN', 'NN', 'NN'],
#  ['DT', 'RB', 'NN', 'NN', 'VBP', 'RB', 'DT', 'WRB', 'JJ', 'NN'],
#  ['WRB',
#   'DT',
#   'NN',
#   'VBP',
#   'RB',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   'PRP',
#   'RB',
#   'VBP',
#   'JJ',
#   'NN',
#   'NN'],
#  ['JJ', 'NN', 'NN', 'IN', 'PRP$', 'NN', 'NN', 'VBP', 'JJ', 'PRP$', 'NN', 'NN'],
#  ['NN',
#   'VBP',
#   'NN',
#   'VB',
#   'PRP$',
#   'JJ',
#   'VBG',
#   'DT',
#   'NN',
#   'NN',
#   'PRP',
#   'VBD',
#   'JJ'],
#  ['NN', 'NN'],
#  ['DT', 'NN', 'NN', 'NN'],
#  ['NN', 'VBD', 'JJ', 'NN', 'PRP', 'RB', 'VB', 'NN', 'PRP', 'VBP', 'VB'],
#  ['NN', 'VBD', 'IN', 'NN', 'NN', 'NN', 'NN', 'NN'],
#  ['DT',
#   'DT',
#   'NN',
#   'CC',
#   'DT',
#   'RB',
#   'DT',
#   'DT',
#   'NN',
#   'NN',
#   'JJ',
#   'IN',
#   'JJ',
#   'NN',
#   'PRP$',
#   'NN',
#   'MD',
#   'VB',
#   'JJ',
#   'NN'],
#  ['DT', 'NN', 'DT', 'NN', 'VB', 'DT', 'NN', 'RB'],
#  ['NN', 'WDT', 'IN', 'DT', 'NN', 'WP', 'VBZ', 'DT', 'NN'],
#  ['PDT', 'DT', 'NN', 'VBP', 'DT', 'NN', 'NN', 'VBP', 'RB', 'VB', 'DT', 'NN'],
#  ['CC', 'VB', 'PRP', 'MD', 'VB', 'VBN', 'IN', 'NN'],
#  ['NN',
#   'NNS',
#   'IN',
#   'VBG',
#   'IN',
#   'PRP$',
#   'JJ',
#   'NN',
#   'DT',
#   'NN',
#   'PRP',
#   'MD',
#   'RB',
#   'VB',
#   'RB',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'CC',
#   'NN',
#   'VBD',
#   'JJ',
#   'NN',
#   'JJ',
#   'IN',
#   'PRP',
#   'VBP'],
#  ['VB', 'VBN', 'IN', 'PDT', 'DT', 'NN', 'NN', 'NN', 'NN', 'RB'],
#  ['NN',
#   'DT',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'PRP',
#   'VBD',
#   'PRP$',
#   'JJ',
#   'JJ',
#   'NN',
#   'VBG',
#   'DT',
#   'NN',
#   'NN',
#   'VBP',
#   'VBN',
#   'VBP',
#   'VBN',
#   'IN',
#   'NN',
#   'VBG',
#   'DT',
#   'NN',
#   'RB',
#   'VBP',
#   'PRP',
#   'VB'],
#  ['NN', 'IN', 'PRP', 'NN'],
#  ['VBG', 'IN', 'DT', 'NN', 'VBZ', 'DT', 'JJ', 'NN'],
#  ['NN', 'IN', 'PRP$', 'NN', 'RB', 'VBP', 'DT', 'NN'],
#  ['CC',
#   'VBP',
#   'VBP',
#   'DT',
#   'JJ',
#   'NN',
#   'WDT',
#   'VBZ',
#   'JJ',
#   'IN',
#   'PRP',
#   'MD',
#   'VB',
#   'DT',
#   'NN',
#   'NN',
#   'NN',
#   'RB',
#   'VBD',
#   'DT',
#   'VBZ',
#   'WRB',
#   'JJ',
#   'VB',
#   'VBG',
#   'JJ'],
#  ['IN', 'DT', 'NN', 'PRP', 'VBP', 'JJ', 'NN'],
#  ['NN',
#   'VBZ',
#   'VBN',
#   'RB',
#   'JJ',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   'NN',
#   'JJ',
#   'NN'],
#  ['JJ',
#   'NN',
#   'PRP',
#   'VBD',
#   'VBG',
#   'JJ',
#   'NNS',
#   'VBP',
#   'VBG',
#   'DT',
#   'NN',
#   'VBD',
#   'DT',
#   'NN'],
#  ['NNS', 'VBP', 'NN', 'TO', 'PRP$', 'WP', 'JJ', 'NN', 'NN', 'IN', 'NN'],
#  ['VB',
#   'PRP',
#   'VB',
#   'DT',
#   'NNS',
#   'VBP',
#   'RB',
#   'IN',
#   'NN',
#   'JJ',
#   'NNS',
#   'VBP',
#   'IN',
#   'DT',
#   'NN',
#   'VBP',
#   'IN',
#   'PRP',
#   'VBP',
#   'IN',
#   'NN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NNS'],
#  ['VB', 'RB', 'VB', 'DT', 'RB', 'VB', 'VBP', 'RB', 'VB', 'DT', 'NN', 'NN'],
#  ['VBP',
#   'RB',
#   'VB',
#   'PRP',
#   'VB',
#   'PRP',
#   'VB',
#   'IN',
#   'JJ',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   'DT',
#   'NN',
#   'VBP',
#   'PRP$',
#   'JJ',
#   'NN',
#   'IN',
#   'NN'],
#  ['VB',
#   'RB',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   'PRP',
#   'VBP',
#   'VBP',
#   'IN',
#   'DT',
#   'NN',
#   'PRP',
#   'VBP',
#   'RB',
#   'VB',
#   'NN',
#   'VB',
#   'JJ',
#   'NN',
#   'TO',
#   'VB'],
#  ['VB',
#   'RB',
#   'PRP',
#   'RB',
#   'VB',
#   'PRP$',
#   'NN',
#   'RB',
#   'PRP',
#   'VBP',
#   'PRP',
#   'JJ',
#   'NN'],
#  ['VBD',
#   'DT',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   'VBP',
#   'IN',
#   'NN',
#   'VBN',
#   'VBN',
#   'NN',
#   'DT',
#   'NN',
#   'RB'],
#  ['JJ', 'NN', 'VBP', 'JJ', 'NN'],
#  ['VB', 'DT', 'NN', 'IN', 'DT', 'JJ', 'NN', 'NN'],
#  ['IN', 'PRP', 'VB', 'JJ', 'VB', 'IN', 'DT', 'NN'],
#  ['NN', 'NN', 'RBR', 'IN', 'DT', 'NN', 'IN', 'TO', 'PRP'],
#  ['NN',
#   'WP',
#   'VBP',
#   'IN',
#   'PRP',
#   'DT',
#   'PRP',
#   'WRB',
#   'PRP$',
#   'IN',
#   'NN',
#   'IN',
#   'DT'],
#  ['IN', 'DT', 'JJ', 'NN', 'EX', 'VBZ', 'DT', 'JJ', 'NN', 'IN', 'VBG', 'PRP$'],
#  ['JJ', 'JJ', 'DT', 'NN', 'NN', 'WDT', 'VBZ', 'NN'],
#  ['JJ',
#   'NNS',
#   'IN',
#   'PRP',
#   'DT',
#   'JJ',
#   'VBP',
#   'DT',
#   'JJ',
#   'NN',
#   'WP',
#   'DT',
#   'NN',
#   'VBP',
#   'VBG',
#   'NN',
#   'JJ',
#   'VBP',
#   'VB',
#   'PRP$',
#   'NN',
#   'VB'],
#  ['JJ',
#   'CD',
#   'NNS',
#   'VBP',
#   'PRP$',
#   'JJ',
#   'NN',
#   'VBD',
#   'PRP$',
#   'NN',
#   'NN',
#   'NN',
#   'VB',
#   'PRP',
#   'PRP'],
#  ['NN',
#   'NN',
#   'NN',
#   'IN',
#   'JJ',
#   'DT',
#   'JJ',
#   'VBP',
#   'VBZ',
#   'DT',
#   'NN',
#   'TO',
#   'VB',
#   'NN',
#   'IN',
#   'JJ',
#   'IN',
#   'JJ',
#   'NN',
#   'CC',
#   'NN'],
#  ['VB', 'PRP', 'IN', 'VBD', 'NN', 'PRP', 'VBZ', 'JJ', 'NN'],
#  ['VB', 'PRP$', 'IN', 'RB', 'TO', 'VB', 'DT', 'JJ', 'JJR'],
#  ['NN',
#   'IN',
#   'NN',
#   'VBD',
#   'PRP',
#   'RP',
#   'JJ',
#   'NN',
#   'NN',
#   'TO',
#   'IN',
#   'PRP',
#   'VBD',
#   'PRP',
#   'IN',
#   'DT',
#   'NN',
#   'DT',
#   'NN',
#   'PRP'],
#  ['WRB', 'VB', 'PRP', 'VB', 'PRP$', 'NN', 'NN', 'NN', 'NN'],
#  ['VB',
#   'PRP',
#   'VBN',
#   'PRP$',
#   'NN',
#   'VBP',
#   'PRP',
#   'VBN',
#   'PRP$',
#   'NN',
#   'IN',
#   'JJ',
#   'VBP',
#   'RB',
#   'VBN',
#   'MD',
#   'PRP',
#   'VB',
#   'RB',
#   'JJ'],
#  ['PRP', 'DT', 'NN', 'IN', 'VBG', 'IN', 'PRP', 'VBZ', 'IN', 'NN'],
#  ['PRP', 'VBD', 'TO', 'DT', 'JJ', 'NN', 'JJ', 'NN', 'NN', 'JJ'],
#  ['PRP',
#   'RB',
#   'VB',
#   'PRP$',
#   'JJ',
#   'CC',
#   'JJ',
#   'VBP',
#   'RB',
#   'RB',
#   'VB',
#   'PRP$',
#   'VBG',
#   'NN',
#   'JJ',
#   'JJ',
#   'NN',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   'IN',
#   'NN',
#   'NN',
#   'CC',
#   'DT',
#   'VBZ',
#   'JJ',
#   'NN'],
#  ['PRP$',
#   'JJ',
#   'NN',
#   'DT',
#   'PRP',
#   'PRP$',
#   'NN',
#   'DT',
#   'PRP',
#   'PRP$',
#   'NN',
#   'CC',
#   'DT',
#   'PRP',
#   'CC',
#   'PRP',
#   'VBZ',
#   'DT',
#   'PRP',
#   'PRP',
#   'VBZ',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   'JJ',
#   'NN',
#   'NN'],
#  ['NN',
#   'VBP',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'WDT',
#   'VBD',
#   'DT',
#   'VBN',
#   'NN',
#   'IN',
#   'NN',
#   'WP',
#   'DT',
#   'NN'],
#  ['NN', 'NN', 'PRP', 'RB', 'EX'],
#  ['WRB',
#   'IN',
#   'PRP',
#   'VBP',
#   'DT',
#   'DT',
#   'JJ',
#   'NN',
#   'CC',
#   'VB',
#   'PRP',
#   'TO',
#   'VB',
#   'CC',
#   'JJ',
#   'NN',
#   'NN',
#   'IN',
#   'PRP',
#   'MD',
#   'VB',
#   'PRP$'],
#  ['WRB', 'JJ', 'IN', 'VBZ', 'PRP', 'DT', 'NN'],
#  ['WRB',
#   'JJ',
#   'VBG',
#   'TO',
#   'VB',
#   'NN',
#   'NN',
#   'NN',
#   'VBP',
#   'WRB',
#   'PRP',
#   'VBG',
#   'TO',
#   'VB',
#   'NN',
#   'NN',
#   'NN',
#   'NN'],
#  ['WRB', 'PRP', 'VBG', 'JJ', 'NN', 'VBZ', 'JJ'],
#  ['NN',
#   'VBP',
#   'PRP$',
#   'JJ',
#   'NN',
#   'DT',
#   'NN',
#   'WDT',
#   'NN',
#   'PRP',
#   'VBP',
#   'RB',
#   'VB',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'CD',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'PRP',
#   'VBP',
#   'IN',
#   'VBZ',
#   'JJ',
#   'NN'],
#  ['NN', 'VBP', 'DT', 'NN', 'RB', 'IN', 'DT', 'RB', 'NN', 'NN', 'NN', 'NN'],
#  ['NN', 'VBP', 'PRP', 'PRP$', 'NN'],
#  ['NN',
#   'MD',
#   'RB',
#   'VB',
#   'DT',
#   'NN',
#   'CC',
#   'DT',
#   'NN',
#   'MD',
#   'RB',
#   'VB',
#   'JJ',
#   'NN',
#   'NN'],
#  ['NNS', 'VBP', 'RB', 'VB', 'IN', 'NN', 'NN', 'VBP', 'IN', 'NN', 'NN', 'NN'],
#  ['NNS',
#   'VBP',
#   'RB',
#   'VB',
#   'DT',
#   'NNS',
#   'VBP',
#   'PRP',
#   'VBZ',
#   'PRP',
#   'CC',
#   'PRP',
#   'VBP'],
#  ['NN',
#   'VBD',
#   'RB',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'NN',
#   'VBZ',
#   'VBN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'JJ',
#   'NN',
#   'IN',
#   'NN'],
#  ['NN', 'NNS', 'VBP', 'VBN', 'NNS'],
#  ['NN',
#   'VBD',
#   'DT',
#   'JJ',
#   'NN',
#   'TO',
#   'VB',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'PRP$',
#   'NN',
#   'NN'],
#  ['NN',
#   'VBG',
#   'NN',
#   'WDT',
#   'VBP',
#   'RB',
#   'JJ',
#   'NN',
#   'VBP',
#   'NN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'RB',
#   'JJ',
#   'VB',
#   'PRP$'],
#  ['NN',
#   'VBD',
#   'DT',
#   'NN',
#   'VBN',
#   'PRP',
#   'IN',
#   'IN',
#   'VBD',
#   'NN',
#   'JJ',
#   'NN',
#   'PRP',
#   'VBG',
#   'VB',
#   'IN',
#   'PRP$',
#   'JJ',
#   'NN',
#   'PRP',
#   'VBP'],
#  ['NN', 'VBD', 'DT', 'NN', 'PRP', 'VBD', 'PRP', 'VB', 'VBG', 'NN', 'NN'],
# ...
#  ['MD',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'CC',
#   'DT',
#   'DT',
#   'DT',
#   'JJ',
#   'VBP',
#   'PRP',
#   'VBP',
#   'NN',
#   'CC',
#   'VB',
#   'DT',
#   'JJ',
#   'DT',
#   'PRP',
#   'VBP',
#   'DT',
#   'NN'],
#  ['VBZ', 'JJ', 'IN', 'JJ', 'NN'],
#  ['TO', 'VBN', 'JJ', 'NN', 'NN', 'JJ', 'NN', 'NN', 'NN', 'VBD', 'JJ', 'JJ'],
#  ['VBZ', 'JJ', 'IN', 'JJ', 'NN'],
#  ['NN', 'NN', 'VBD', 'CD'],
#  ['DT', 'NN', 'NN', 'VBD', 'NN', 'IN'],
#  ['PRP',
#   'MD',
#   'VB',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   'TO',
#   'CD',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'TO'],
#  ['NN',
#   'NN',
#   'VBZ',
#   'RB',
#   'VBG',
#   'PRP',
#   'MD',
#   'VB',
#   'DT',
#   'JJ',
#   'RB',
#   'NN',
#   'JJ',
#   'NN',
#   'CC',
#   'VB',
#   'PRP$',
#   'NN'],
#  [],
#  ['NNS', 'VBP', 'RB', 'VB', 'NN', 'RB'],
#  ['VB', 'PRP', 'VB', 'DT', 'JJ', 'NN', 'WDT', 'VBZ', 'VBG'],
#  ['NN', 'IN', 'NN', 'VBZ', 'JJ', 'NN', 'NN'],
#  ['JJ', 'NNS', 'VBP', 'IN', 'NN', 'JJ'],
#  ['CD', 'CD', 'JJ', 'VBN', 'NN', 'RB', 'PRP$', 'NN'],
#  ['NN',
#   'PRP',
#   'VBP',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   'PRP',
#   'VBP',
#   'VBG',
#   'PRP',
#   'JJ',
#   'NN'],
#  ['RB', 'RB', 'NN', 'WDT', 'NN', 'TO', 'DT', 'NN', 'RB', 'VBD'],
#  ['NN',
#   'NN',
#   'VBG',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'CC',
#   'JJ',
#   'NN',
#   'PRP',
#   'VBD',
#   'NN',
#   'NN',
#   'NN',
#   'CC',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   'PRP',
#   'VBD',
#   'PRP'],
#  ['JJ',
#   'VBD',
#   'TO',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'WRB',
#   'PRP',
#   'VBD',
#   'DT',
#   'NN',
#   'DT',
#   'JJ',
#   'JJR',
#   'NN',
#   'NN',
#   'PRP',
#   'RB',
#   'PRP',
#   'VB',
#   'MD',
#   'RB',
#   'VB',
#   'DT',
#   'NN',
#   'NN'],
#  ['IN',
#   'VBN',
#   'VBP',
#   'DT',
#   'NN',
#   'NN',
#   'NN',
#   'VBP',
#   'DT',
#   'JJ',
#   'NN',
#   'VBP',
#   'NN',
#   'CC',
#   'VB',
#   'DT',
#   'NN',
#   'MD',
#   'VB',
#   'VB',
#   'RB',
#   'IN',
#   'NN',
#   'CC',
#   'NN'],
#  ['JJ', 'NN', 'RB', 'MD', 'VB', 'VB', 'DT', 'VBG'],
#  ['VBN', 'VBD', 'IN', 'JJ', 'NN'],
#  ['JJ',
#   'RB',
#   'VBD',
#   'NN',
#   'CC',
#   'DT',
#   'NN',
#   'VBP',
#   'IN',
#   'NNS',
#   'RB',
#   'CC',
#   'PRP',
#   'VBP',
#   'VBG',
#   'RB',
#   'JJR',
#   'NN',
#   'TO',
#   'VB',
#   'JJ',
#   'NN',
#   'VB',
#   'RP',
#   'NN'],
#  ['VBD', 'VBN', 'IN', 'DT', 'RB'],
#  ['VB', 'DT', 'CD', 'NN', 'IN', 'NN', 'NN', 'VBP', 'VBG', 'PRP'],
#  ['VBN', 'NN', 'NN'],
#  ['NN',
#   'NN',
#   'RB',
#   'JJ',
#   'JJ',
#   'PRP',
#   'MD',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'CD',
#   'NN'],
#  ['VB',
#   'PRP$',
#   'NN',
#   'TO',
#   'VB',
#   'DT',
#   'JJ',
#   'NNS',
#   'DT',
#   'JJ',
#   'TO',
#   'CC',
#   'VBG',
#   'DT'],
#  ['PRP', 'VBP', 'JJ', 'TO', 'VB', 'JJ', 'NN'],
#  ['EX',
#   'VBP',
#   'DT',
#   'JJ',
#   'JJ',
#   'CD',
#   'CC',
#   'VB',
#   'JJ',
#   'NN',
#   'VBZ',
#   'RB',
#   'WRB',
#   'PRP',
#   'IN',
#   'DT'],
#  ['JJ',
#   'NN',
#   'NN',
#   'CC',
#   'JJ',
#   'NN',
#   'DT',
#   'VBD',
#   'RB',
#   'JJ',
#   'NN',
#   'CC',
#   'DT',
#   'NN'],
#  [],
#  ['NN'],
#  ['IN', 'DT', 'NN', 'NN', 'CC', 'NN', 'NN', 'DT'],
#  ['VBG', 'NN', 'NN'],
#  ['DT', 'JJ', 'NN'],
#  ['VBN', 'NNS', 'CC', 'WDT', 'VBP', 'RB', 'PRP', 'IN', 'NN', 'NN'],
#  ['VBP',
#   'RB',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   'VBZ',
#   'JJ',
#   'VBP',
#   'RB',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'PRP',
#   'VBP'],
#  ['VBZ', 'DT', 'NN', 'IN', 'JJ', 'NN'],
#  ['VB',
#   'RP',
#   'WRB',
#   'DT',
#   'NN',
#   'NN',
#   'CC',
#   'NN',
#   'TO',
#   'VB',
#   'JJ',
#   'CC',
#   'VBD',
#   'MD',
#   'NN',
#   'JJ',
#   'IN',
#   'CC',
#   'VB'],
#  ['VBG'],
#  ['PRP', 'VBP', 'RB', 'VB', 'DT', 'NN'],
#  ['NN'],
#  ['NN', 'VBZ', 'JJ', 'NN', 'VBG', 'IN', 'DT', 'NN', 'NN'],
#  ['NN',
#   'IN',
#   'NN',
#   'NN',
#   'VBZ',
#   'JJ',
#   'NN',
#   'MD',
#   'VB',
#   'VB',
#   'DT',
#   'NN',
#   'NN',
#   'IN',
#   'PRP',
#   'VBZ',
#   'NN',
#   'IN',
#   'PRP$',
#   'NN'],
#  ['JJ', 'JJ', 'CC', 'PRP$', 'NN', 'CD', 'JJ', 'NN', 'JJ', 'NN'],
#  ['RB', 'VBG', 'IN', 'PRP', 'VBP', 'DT', 'NN', 'NN', 'PRP', 'VBZ', 'RB', 'JJ'],
#  ['VBG', 'RP', 'RB', 'NN'],
#  ['DT', 'NN', 'VBZ', 'PRP$', 'NN', 'VBD', 'IN', 'IN', 'NN'],
#  ['VB',
#   'RB',
#   'VB',
#   'VBD',
#   'PRP$',
#   'JJ',
#   'NN',
#   'VBP',
#   'DT',
#   'NN',
#   'VBP',
#   'DT',
#   'NN',
#   'VBP',
#   'RB',
#   'JJ',
#   'IN'],
#  ['RB', 'NNS'],
#  [],
#  ['VB',
#   'PRP',
#   'JJ',
#   'RB',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'TO',
#   'VB',
#   'NN',
#   'NN',
#   'VB',
#   'VBN',
#   'MD',
#   'VB',
#   'DT',
#   'NN',
#   'NN'],
#  [],
#  [],
#  ['NN'],
#  ['NN', 'NN', 'IN', 'PRP'],
#  ['NN', 'NN', 'NN', 'JJ', 'NN', 'NN', 'IN', 'JJ', 'NN', 'IN', 'PRP'],
#  ['JJ', 'NN', 'NN', 'VBP', 'NN', 'NN', 'DT', 'DT', 'JJ', 'IN'],
#  ['MD',
#   'VB',
#   'PRP',
#   'CC',
#   'JJ',
#   'VBP',
#   'VBG',
#   'NN',
#   'VBZ',
#   'NN',
#   'VBD',
#   'PRP',
#   'RP'],
#  ['CC',
#   'NN',
#   'VBZ',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'NN',
#   'RB',
#   'RB',
#   'VBN',
#   'JJ',
#   'NN',
#   'JJ',
#   'NN',
#   'JJ',
#   'NN',
#   'NN'],
#  ['RBR', 'RB', 'CC', 'JJ', 'NN'],
#  ['JJ', 'NN', 'JJ', 'NN', 'NN', 'IN', 'NN'],
#  ['JJ', 'JJ', 'NN', 'NN'],
#  ['NN', 'NN', 'IN', 'JJ'],
#  ['RB', 'JJ', 'NN', 'NN', 'NN'],
#  ['JJ', 'NN', 'NN', 'VBN', 'IN', 'NN', 'CC', 'IN'],
#  ['NN', 'NN', 'NN'],
#  ['NN', 'DT', 'NN', 'VBG', 'PRP$', 'NN', 'IN', 'JJ', 'NN'],
#  ['NN', 'NN', 'NN', 'JJ', 'NN', 'NN', 'IN', 'JJ', 'NN'],
#  ['RB', 'DT', 'NN', 'VBD', 'RP'],
#  ['VBG', 'NN', 'CC', 'VBD', 'NN'],
#  ['JJ', 'NN', 'NN', 'NN', 'VBD', 'RP'],
#  ['NN', 'IN', 'NN', 'NN', 'NN'],
#  ['JJ', 'NN', 'VBD', 'RP'],
#  ['JJ', 'JJ', 'NN', 'JJ', 'NN', 'NN', 'VBP'],
#  ['NN', 'JJ', 'NN', 'NN', 'VBD', 'DT', 'NN'],
#  ['NN'],
#  ['NN'],
#  ['NN', 'NN', 'NN', 'IN', 'JJ', 'JJ', 'NN'],
#  ['JJ', 'CC', 'JJ', 'NN', 'CC', 'NN', 'NN'],
#  ['NN', 'NN', 'NN', 'NN', 'VBN', 'CC', 'VBN'],
#  ['JJ', 'VB', 'PRP$', 'NN', 'VBD', 'JJ', 'NN'],
#  ['RBR', 'JJ', 'NN', 'IN', 'VBG', 'DT', 'JJ', 'NN'],
#  ['JJ', 'NN', 'NN'],
#  ['NN', 'JJ', 'NN', 'NN', 'VBG', 'IN', 'NN'],
#  ['JJ', 'NN', 'VBD', 'DT', 'NN', 'IN', 'PRP$', 'NN', 'JJ', 'NN'],
#  ['NN', 'NN'],
#  ['NN', 'NN'],
#  ['NN', 'NN', 'CC', 'NN', 'IN', 'NN', 'NN'],
#  ['JJ', 'NN', 'VBG', 'NN', 'NN'],
#  ['JJ', 'NN', 'NN', 'IN', 'DT', 'JJ', 'NN'],
#  ['NN', 'VBD', 'PRP$', 'NN', 'VBG', 'PRP$', 'NN'],
#  ['VBG', 'PRP$', 'JJ', 'NN', 'NN', 'NN', 'VBD', 'NN'],
#  ['PRP$', 'NN', 'NN'],
#  ['RB', 'JJ', 'JJ', 'JJ', 'JJ', 'JJ', 'NN', 'VBD', 'NNS'],
#  ['JJ', 'JJ', 'NN', 'JJ', 'NN', 'NN', 'VBD'],
#  ['JJ', 'VBP', 'NN'],
#  ['NN', 'JJ', 'VB', 'PRP$', 'NN', 'VBD'],
#  ['JJ', 'NN', 'JJ', 'NN'],
#  ['NN', 'IN', 'JJ', 'NN'],
#  ['NN', 'NN', 'VBG', 'NN'],
#  ['NN', 'IN', 'JJ', 'VBG', 'PRP$', 'NN', 'NN', 'VBD'],
#  ['DT', 'RB', 'JJ', 'JJ', 'NN', 'VBZ', 'JJ'],
#  ['JJ', 'NN', 'NN', 'VBG', 'JJ', 'NN'],
#  ['JJ', 'NN', 'VBG', 'JJ', 'CC', 'JJ', 'NN', 'IN', 'PRP$', 'NN'],
#  ['JJ', 'NN', 'NN', 'IN', 'VBG', 'IN', 'RB', 'PRP$', 'NN'],
#  ['NN', 'NN', 'VBD', 'JJ', 'NN'],
#  ['NN', 'NN', 'NN', 'NN', 'VBD', 'JJ', 'NN'],
#  ['NN', 'NN', 'VBG'],
#  ['DT',
#   'NN',
#   'CD',
#   'MD',
#   'VB',
#   'RB',
#   'JJ',
#   'JJR',
#   'IN',
#   'PRP',
#   'VBD',
#   'DT',
#   'NN',
#   'IN',
#   'PRP'],
#  ['VB',
#   'RB',
#   'VB',
#   'PRP',
#   'IN',
#   'PRP$',
#   'IN',
#   'NN',
#   'DT',
#   'PRP',
#   'IN',
#   'PRP',
#   'IN',
#   'VBN',
#   'VBP',
#   'JJ'],
#  ['IN',
#   'PRP',
#   'DT',
#   'PRP',
#   'DT',
#   'NN',
#   'TO',
#   'VB',
#   'JJ',
#   'IN',
#   'NN',
#   'VBP',
#   'RB',
#   'VB',
#   'TO',
#   'VB',
#   'NN',
#   'JJR',
#   'RB',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   'TO',
#   'PRP'],
#  ['JJ', 'NN'],
#  ['PRP', 'DT', 'NN', 'VBD', 'NNS', 'RP'],
#  ['VB',
#   'DT',
#   'JJ',
#   'NN',
#   'NN',
#   'IN',
#   'CC',
#   'DT',
#   'VBZ',
#   'WRB',
#   'PRP',
#   'VBP',
#   'RB',
#   'JJ',
#   'JJ'],
#  ['MD',
#   'JJ',
#   'NN',
#   'IN',
#   'PRP',
#   'VBP',
#   'DT',
#   'NN',
#   'VB',
#   'DT',
#   'IN',
#   'VBG',
#   'RP',
#   'VBG',
#   'VBZ',
#   'IN',
#   'DT',
#   'NN'],
#  ['PRP', 'VBG', 'DT', 'JJ', 'NN'],
#  ['PRP$', 'JJ', 'JJ', 'NN'],
#  ['TO',
#   'WRB',
#   'NN',
#   'VBN',
#   'TO',
#   'VB',
#   'JJ',
#   'IN',
#   'VBG',
#   'RB',
#   'VBZ',
#   'NN',
#   'VBD'],
#  ['WRB', 'NN', 'VBD', 'PRP$', 'JJ', 'NN', 'NN'],
#  ['NN',
#   'IN',
#   'NNS',
#   'VBN',
#   'TO',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'VBZ',
#   'JJ',
#   'NN',
#   'NN',
#   'RB',
#   'JJ'],
#  ['TO', 'VBG', 'VB', 'VBG', 'JJ', 'NN', 'PRP', 'VBD'],
#  ['JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'WP',
#   'MD',
#   'RB',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   'NN'],
#  ['PRP$', 'NN'],
#  ['NN', 'PRP', 'RB', 'VB', 'RB', 'RP', 'PRP', 'VBP', 'VB', 'PRP', 'RP', 'NN'],
#  ['NN', 'NN', 'JJ', 'NN', 'NN', 'IN', 'IN', 'IN', 'PRP', 'VBZ', 'JJ'],
#  ['VBG',
#   'DT',
#   'NN',
#   'DT',
#   'NN',
#   'NN',
#   'VBZ',
#   'VBG',
#   'DT',
#   'NN',
#   'RB',
#   'VB',
#   'DT',
#   'NNS',
#   'VBP'],
#  [],
#  ['NN'],
#  ['PDT', 'DT', 'JJ', 'NN'],
#  ['NN', 'NNS', 'IN'],
#  ['NN',
#   'NN',
#   'VBP',
#   'IN',
#   'DT',
#   'NN',
#   'PRP',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'VBG',
#   'RP',
#   'PDT',
#   'DT',
#   'NN'],
#  ['NN',
#   'IN',
#   'NN',
#   'WP',
#   'VBG',
#   'IN',
#   'NN',
#   'WRB',
#   'VBP',
#   'DT',
#   'NN',
#   'NN',
#   'NNS'],
#  ['IN', 'PDT', 'DT', 'JJ', 'NN'],
#  ['NN',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'JJ',
#   'NN',
#   'NN',
#   'WDT',
#   'VBZ',
#   'NN',
#   'IN',
#   'DT',
#   'NN'],
#  ['NN',
#   'NN',
#   'CC',
#   'RB',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'TO',
#   'CC',
#   'VB',
#   'VBP',
#   'VBG',
#   'RP',
#   'DT',
#   'NN',
#   'TO',
#   'VB',
#   'VBD',
#   'RB',
#   'IN',
#   'PRP',
#   'VBP',
#   'RB',
#   'DT',
#   'NN',
#   'VBN',
#   'IN',
#   'PRP',
#   'IN',
#   'NN',
#   'NN'],
#  ['NN',
#   'RP',
#   'DT',
#   'NN',
#   'NN',
#   'CC',
#   'JJ',
#   'NN',
#   'TO',
#   'VB',
#   'CC',
#   'VB',
#   'PRP',
#   'CC',
#   'CD',
#   'IN',
#   'PRP$',
#   'NN',
#   'NN',
#   'IN',
#   'PRP',
#   'VBD',
#   'PRP'],
#  ['NN', 'NN', 'NN', 'NN', 'VBD', 'DT', 'NN', 'NN', 'NN', 'NN', 'IN', 'NNS'],
#  ['DT', 'NN', 'IN', 'NN'],
#  ['NN', 'VBP', 'NN', 'RB', 'VBD', 'PRP', 'VBP', 'VB', 'DT', 'NN'],
#  ['CC', 'NN', 'NN'],
#  ['DT',
#   'NN',
#   'IN',
#   'PRP$',
#   'NN',
#   'NN',
#   'JJ',
#   'NN',
#   'VBD',
#   'IN',
#   'JJS',
#   'CD',
#   'NN'],
#  ['PRP', 'JJ', 'IN', 'DT', 'JJ', 'NN', 'VB', 'DT', 'NN', 'RB'],
#  ['NN',
#   'NN',
#   'NN',
#   'VBP',
#   'PRP',
#   'CC',
#   'PRP',
#   'DT',
#   'PRP',
#   'CC',
#   'VB',
#   'VBP',
#   'PRP',
#   'NN',
#   'VBZ',
#   'VBG'],
#  ['DT', 'PRP', 'VBD', 'DT', 'NN', 'NN', 'IN', 'VBG', 'NN'],
#  ['DT',
#   'JJ',
#   'NN',
#   'NN',
#   'IN',
#   'DT',
#   'RB',
#   'NN',
#   'RB',
#   'VB',
#   'VBG',
#   'IN',
#   'NN'],
#  ['DT', 'NN', 'VBD', 'VBG', 'IN', 'PRP$', 'NN', 'VBD', 'JJ', 'NNS'],
#  ['NN', 'VBG', 'RP', 'NN'],
#  ['RB',
#   'VBN',
#   'DT',
#   'NN',
#   'VBD',
#   'RP',
#   'IN',
#   'NN',
#   'NN',
#   'DT',
#   'CC',
#   'RB',
#   'VBD',
#   'NN',
#   'VBD',
#   'DT',
#   'NN',
#   'VBD',
#   'DT'],
#  ['NN',
#   'CC',
#   'NN',
#   'VBG',
#   'PRP$',
#   'PRP',
#   'VBD',
#   'PRP$',
#   'PRP',
#   'VBG',
#   'IN',
#   'DT',
#   'NN',
#   'CC',
#   'PRP',
#   'RB',
#   'IN',
#   'PRP$',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   'NN'],
#  ['NN', 'VBG', 'JJR', 'NN', 'IN', 'NN', 'NN', 'IN'],
#  ['NN',
#   'VBP',
#   'RB',
#   'IN',
#   'PRP',
#   'VBP',
#   'DT',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'VBG',
#   'IN',
#   'PRP',
#   'TO',
#   'VB',
#   'DT',
#   'NN'],
#  ['NN',
#   'VB',
#   'MD',
#   'RB',
#   'VB',
#   'VBN',
#   'JJR',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'CC',
#   'DT',
#   'NN'],
#  ['NN',
#   'VB',
#   'PRP',
#   'DT',
#   'VBP',
#   'NN',
#   'NN',
#   'TO',
#   'PRP$',
#   'NN',
#   'NN',
#   'IN',
#   'VBG',
#   'VBN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN'],
#  ['PRP$'],
#  ['CD',
#   'PRP',
#   'DT',
#   'VBP',
#   'NN',
#   'IN',
#   'NN',
#   'RP',
#   'JJ',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'VBP',
#   'IN',
#   'VBP',
#   'JJ',
#   'JJ',
#   'NN',
#   'RB',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   'NN'],
#  ['NN',
#   'PRP',
#   'VBP',
#   'VBN',
#   'DT',
#   'PRP',
#   'IN',
#   'DT',
#   'NN',
#   'VBP',
#   'RB',
#   'VB',
#   'JJ',
#   'WRB',
#   'PRP$',
#   'JJ',
#   'NN',
#   'VBG',
#   'PRP',
#   'VBD',
#   'PRP',
#   'RB'],
#  ['VBD', 'CC', 'VB', 'NN', 'VBG', 'IN', 'PRP$', 'JJ', 'NN'],
#  ['IN',
#   'JJ',
#   'NN',
#   'RB',
#   'NN',
#   'IN',
#   'PRP',
#   'VBP',
#   'PRP',
#   'IN',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'VBG',
#   'NNS',
#   'IN',
#   'JJ',
#   'NN',
#   'PRP',
#   'VBP',
#   'PRP',
#   'PRP$',
#   'NN',
#   'IN',
#   'NN'],
#  ['PRP', 'VBP', 'VB', 'VBG', 'NN', 'PRP', 'VBZ', 'NN'],
#  ['NN',
#   'NN',
#   'NN',
#   'VBD',
#   'PRP',
#   'NN',
#   'NN',
#   'PRP',
#   'VB',
#   'NN',
#   'NN',
#   'TO',
#   'IN',
#   'RP'],
#  ['JJ', 'NN', 'IN', 'PRP', 'VB', 'IN'],
#  ['NN',
#   'MD',
#   'PRP$',
#   'JJ',
#   'NN',
#   'JJ',
#   'VB',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'PRP',
#   'MD',
#   'VB',
#   'VBG',
#   'RB',
#   'DT',
#   'NN',
#   'IN',
#   'JJ',
#   'NN'],
#  ['IN', 'PRP', 'VBP', 'DT', 'NN', 'VB', 'IN', 'RP', 'PRP$', 'NN', 'NN'],
#  ['IN',
#   'NN',
#   'NN',
#   'VBP',
#   'PRP',
#   'IN',
#   'DT',
#   'JJ',
#   'FW',
#   'PRP$',
#   'RB',
#   'RB',
#   'JJ',
#   'NNS',
#   'VBP',
#   'WRB',
#   'PRP',
#   'VBD',
#   'DT',
#   'NN',
#   'IN',
#   'PRP$',
#   'NN',
#   'NN',
#   'JJ',
#   'NN'],
#  ['JJ', 'NN', 'NN', 'IN', 'PRP', 'DT', 'NN'],
#  ['IN', 'DT', 'NN'],
#  ['JJ', 'NN'],
#  ['PRP$', 'NN'],
#  ['VBZ',
#   'DT',
#   'RBS',
#   'JJ',
#   'NN',
#   'PDT',
#   'DT',
#   'JJ',
#   'NN',
#   'CC',
#   'NN',
#   'VBZ',
#   'DT',
#   'DT',
#   'NN',
#   'NN',
#   'WDT'],
#  ['IN', 'NN', 'DT', 'NN', 'VBD', 'JJ', 'NN'],
#  ['NN',
#   'NN',
#   'NN',
#   'VBG',
#   'PRP',
#   'IN',
#   'PRP$',
#   'NN',
#   'NN',
#   'NN',
#   'WDT',
#   'VBZ',
#   'RB',
#   'JJ',
#   'IN',
#   'NN',
#   'NN',
#   'IN',
#   'DT',
#   'NN'],
#  ['JJ',
#   'NN',
#   'RB',
#   'JJ',
#   'TO',
#   'VB',
#   'VBG',
#   'PRP$',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'JJ',
#   'NN',
#   'NN',
#   'PRP',
#   'VBP'],
#  ['IN',
#   'NN',
#   'IN',
#   'PRP',
#   'VBP',
#   'JJ',
#   'VBG',
#   'RP',
#   'TO',
#   'NN',
#   'NN',
#   'IN',
#   'PRP',
#   'VB',
#   'PRP$',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'PRP',
#   'VBP',
#   'DT',
#   'NN'],
#  ['IN', 'NN', 'DT', 'NNS', 'VBP', 'VB', 'JJ'],
#  ['IN',
#   'IN',
#   'NN',
#   'NN',
#   'VBZ',
#   'JJ',
#   'JJ',
#   'JJ',
#   'NN',
#   'EX',
#   'DT',
#   'NN',
#   'IN',
#   'RB',
#   'VBG',
#   'RP',
#   'DT',
#   'JJ',
#   'DT',
#   'PRP',
#   'JJ'],
#  ['IN',
#   'IN',
#   'PRP',
#   'DT',
#   'VBP',
#   'VBG',
#   'NN',
#   'NN',
#   'NN',
#   'VBP',
#   'DT',
#   'NN',
#   'IN',
#   'PRP$',
#   'NN',
#   'NN',
#   'WRB',
#   'NN',
#   'VBP',
#   'VBG',
#   'PRP',
#   'IN',
#   'DT',
#   'NN'],
#  ['IN',
#   'NN',
#   'IN',
#   'NN',
#   'NN',
#   'NN',
#   'VBP',
#   'VBN',
#   'PRP',
#   'NN',
#   'IN',
#   'DT',
#   'PRP$',
#   'WP',
#   'VBD',
#   'PRP',
#   'VB',
#   'IN',
#   'JJ',
#   'NN'],
#  ['IN',
#   'JJ',
#   'PRP$',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'DT',
#   'DT',
#   'NN',
#   'WDT',
#   'VBZ',
#   'NN',
#   'NN',
#   'CD'],
#  ['IN', 'NN', 'NN', 'NN', 'NN', 'VBN'],
#  ['IN', 'JJ', 'NN', 'NN', 'PRP', 'VBP', 'TO', 'VB', 'VBG', 'RP'],
#  ['IN',
#   'JJ',
#   'NN',
#   'NN',
#   'VBP',
#   'RB',
#   'VBD',
#   'PRP',
#   'VB',
#   'JJ',
#   'IN',
#   'NN',
#   'VBP',
#   'VBG',
#   'NNS',
#   'NN'],
#  ['IN', 'NN', 'NN', 'VB', 'PRP', 'JJ'],
#  ['RB',
#   'JJ',
#   'NN',
#   'VBG',
#   'NNS',
#   'IN',
#   'PRP',
#   'TO',
#   'PRP',
#   'VBP',
#   'IN',
#   'NN',
#   'VBG',
#   'VBD',
#   'JJ'],
#  ['RB', 'IN', 'DT', 'JJ', 'NN', 'NN', 'PRP', 'VBD', 'NN', 'JJ', 'NN'],
#  ['IN',
#   'IN',
#   'NN',
#   'NN',
#   'VBN',
#   'DT',
#   'WDT',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'JJ',
#   'JJ'],
#  ['IN', 'JJ', 'NN', 'NN', 'NN', 'NN', 'JJ', 'IN', 'NN', 'NN'],
#  ['IN',
#   'RB',
#   'NN',
#   'DT',
#   'PRP',
#   'RB',
#   'VBD',
#   'PRP',
#   'VBG',
#   'RB',
#   'VBP',
#   'RP',
#   'IN',
#   'PRP$',
#   'NN',
#   'NN',
#   'NN',
#   'NN',
#   'IN',
#   'PRP',
#   'VBZ',
#   'RP',
#   'PRP$',
#   'NNS'],
#  ['IN', 'RB', 'NN', 'WRB', 'DT', 'NN', 'NN', 'JJ', 'IN', 'NN'],
#  ['IN', 'JJ', 'IN', 'NN', 'NN', 'VBP', 'PRP', 'VBD', 'NN', 'IN', 'PRP$', 'NN'],
#  ['IN', 'JJ', 'NN', 'NN', 'PRP$', 'NN'],
#  ['IN', 'JJ', 'NN', 'NN', 'NN', 'NN'],
#  ['IN',
#   'IN',
#   'NN',
#   'NN',
#   'RB',
#   'VBD',
#   'IN',
#   'PRP$',
#   'TO',
#   'VB',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'NN',
#   'NN',
#   'PRP',
#   'DT',
#   'VBP',
#   'NN'],
#  ['IN',
#   'JJ',
#   'NN',
#   'NN',
#   'IN',
#   'PRP',
#   'VBP',
#   'PRP',
#   'PRP',
#   'VBP',
#   'RB',
#   'RB',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'VBP',
#   'RB'],
#  ['IN',
#   'JJ',
#   'NN',
#   'VBD',
#   'IN',
#   'JJ',
#   'JJ',
#   'NN',
#   'VBP',
#   'RB',
#   'JJ',
#   'UH',
#   'PRP$',
#   'JJ',
#   'NN',
#   'NN'],
#  ['IN', 'JJ', 'NN', 'DT', 'NN', 'VB', 'RB', 'NN', 'VBD', 'VBN'],
#  ['IN', 'JJ', 'NN', 'NN', 'NN', 'NN', 'IN'],
#  ['IN',
#   'IN',
#   'NN',
#   'NN',
#   'VBP',
#   'PRP',
#   'VBP',
#   'PRP',
#   'VBZ',
#   'DT',
#   'NN',
#   'NN',
#   'VBG',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'VBP',
#   'NN'],
#  ['IN',
#   'RB',
#   'NN',
#   'WRB',
#   'PRP',
#   'VBP',
#   'VBG',
#   'TO',
#   'VB',
#   'CC',
#   'PRP$',
#   'NN',
#   'VBZ',
#   'VBG',
#   'RP',
#   'JJ',
#   'NN'],
#  ['IN', 'JJ', 'NN', 'NN', 'IN', 'RB', 'VBG', 'NN', 'IN', 'NN', 'NN'],
#  ['IN',
#   'JJ',
#   'NN',
#   'NN',
#   'IN',
#   'PRP',
#   'VBP',
#   'DT',
#   'NN',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'PRP',
#   'VB',
#   'RB',
#   'RB',
#   'IN',
#   'NN',
#   'NN'],
#  ['IN',
#   'JJ',
#   'IN',
#   'DT',
#   'NNS',
#   'RB',
#   'JJ',
#   'NN',
#   'VBP',
#   'RB',
#   'RB',
#   'TO',
#   'VB',
#   'NN'],
#  ['IN', 'JJ', 'NN', 'NN', 'NN', 'IN', 'PRP$', 'NN', 'NN', 'IN', 'JJ', 'NN'],
#  ['IN', 'JJ', 'NN', 'JJ', 'NN', 'VBG', 'PRP', 'IN'],
#  ...]

# %%
df['POS'] = list_POS

# %%
def detokenize(tokens):
  return TreebankWordDetokenizer().detokenize(tokens)

# %%
df['detokenized_POS'] = df['POS'].apply(detokenize)

# %%
POSvectorizer = TfidfVectorizer(min_df=1)
X_POS = POSvectorizer.fit_transform(df['detokenized_POS'])

# %% [markdown]
# ## Destokenizador
#
# To do the other features, we have chosen to put back all the tokens that make a sentence. We think that this will make the development of this process easier.

# %%
df['tweets_detokenize_with_emoticon'] = df['preprocessing_with_emoticons'].apply(detokenize)

# %%
df['tweets_detokenize_with_emoticon']
# Out:
# 0        a a woman you should not complain about cleani...
# 1        boy day cold tea down bad for coffin dat he in...
# 2        dawn!!! you ever fuck a bitch and she start to...
# 3                                   she look like a tranny
# 4        the shit you hear about me might be true or it...
#                                ...
# 24778    you a mutual in lie right! his of is trash now...
# 24779    you have gone and broke the wrong heart baby a...
# 24780    young buck anna eat!! dat nigh like i aunt fuc...
# 24781                   you got wild bitch telling you lie
# 24782    ruffled near eleven dahlia beautiful color com...
# Name: tweets_detokenize_with_emoticon, Length: 24783, dtype: object

# %% [markdown]
# ###Sentiment analisis
#
# Thanks to sentiment analysis we will identify and extract subjective characteristics from the tweets to be analyzed. To carry out this task, the VADER library will be used. VADER will return the following values:
#
# - Pos: The probability that the sentiment is positive.
# - Neu: The probability that the sentiment is neutral.
# - Neg: The probability that the sentiment is negative.
# - Compound: The normalized composite score that calculates the sum of all the scores, takes a value between -1 and 1.

# %%
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sentiment_analyzer  = SentimentIntensityAnalyzer() 

negative = []
positive = []
neutral = []
compound = []

for tweet in df['tweets_detokenize_with_emoticon']:
  sentiment = sentiment_analyzer.polarity_scores(tweet)
  negative.append(sentiment['neg'])
  positive.append(sentiment['pos'])
  neutral.append(sentiment['neu'])
  compound.append(sentiment['compound'])
  #aux_negative = []
  #aux_positive = []
  #aux_neutral = []
  #aux_compound = []
  #sentiment = sentiment_analyzer.polarity_scores(tweet)
  #aux_negative.append(sentiment['neg'])
#  aux_positive.append(sentiment['pos'])
#  aux_neutral.append(sentiment['neu'])
#  aux_compound.append(sentiment['compound'])
#  negative.append(aux_negative)
#  positive.append(aux_positive)
#  neutral.append(aux_neutral)
#  compound.append(aux_compound)
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# /usr/local/lib/python3.6/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %% [markdown]
# For example, this is a graphical representation of the sentiment analysis from a tweet.

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(30,1)})
def visualise_sentiments(data):
  sns.heatmap(pd.DataFrame(data).set_index("Sentence").T,center=0, annot=True, cmap = "PiYG")

sentence = df['tweets_detokenize_with_emoticon'][0]
visualise_sentiments({
    "Sentence":["SENTENCE"] + sentence.split(),
    "Sentiment":[sentiment_analyzer.polarity_scores(sentence)["compound"]] + [sentiment_analyzer.polarity_scores(word)["compound"] for word in sentence.split()]
})

# %% [markdown]
# ### Number  of  words & sentences
#
# To calculate the number of words and sentences that each tweet has, we have decided to use the original tweet, without preprocessing, since we think that it is more significant in this aspect than the already processed tweet, which removes words.
#
# So, we are going to load the CSV file with the original tweets, but we will only save the tweet column.

# %%
df_count = pd.read_csv('./labeled_data.csv', usecols = ["tweet"])

# %%
from nltk.tokenize import word_tokenize
nltk.download('punkt')
listNumberWords = []

for tweet in df_count['tweet']: 
  aux = []
  words = word_tokenize(tweet)
  num_words = len(words)
  aux.append(num_words)
  listNumberWords.append(aux)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from nltk.tokenize import sent_tokenize

listNumberSentences = []

for tweet in df_count['tweet']:
  aux = []
  sentences = sent_tokenize(tweet)
  num_sentences = len(sentences)
  aux.append(num_sentences)
  listNumberSentences.append(aux)

# %% [markdown]
# ##Concatenate

# %%
X = np.concatenate([X_TFIDF.toarray(), X_POS.toarray()],axis=1)
X.shape
X = np.column_stack((X,negative,positive,neutral,compound,listNumberWords,listNumberSentences))
X.shape
# Out:
# (24783, 263)

# %% [markdown]
# # 3. Select features
#
# We have created a new dataset where we have put the characteristics with which we will work from now on. With this dataset, feature selection will be made.

# %% [markdown]
# To carry out the selection of characteristics, the selectKBest function will be used. You will have to pass it the number of "top" characteristics that it will choose from the existing ones. As each column is a different word and in our problem we are asked to eliminate 70% of the words, we will only have 30% of our vocabulary.

# %%
# Create features and target variable for Classification problem
X_clf = X
y_clf = df['class'] # Target variable: class
n_k = round(X.shape[1] * 0.3)

best = SelectKBest(score_func = mutual_info_classif, k = n_k)

X = best.fit_transform(X_clf, y_clf)
print("Shape: ",X.shape)

selected = best.get_support(indices=True)
selected
# Out:
# Shape:  (24783, 79)
# array([  0,   1,   4,   6,   8,  11,  12,  13,  14,  24,  25,  26,  27,
#         38,  39,  42,  49,  50,  55,  56,  60,  61,  62,  65,  67,  75,
#         76,  82,  83,  88, 106, 107, 109, 115, 118, 128, 136, 137, 138,
#        144, 147, 152, 156, 157, 161, 165, 167, 168, 180, 182, 188, 190,
#        192, 195, 200, 205, 207, 209, 211, 218, 219, 220, 224, 225, 226,
#        227, 230, 231, 233, 235, 236, 240, 248, 249, 256, 257, 258, 259,
#        260])

# %% [markdown]
# # 4. Classification algorithm

# %% [markdown]
# ## Single Validation

# %% [markdown]
# Once we know the three characteristics with which we are going to work, it is time to separate the dataset records in the training part and the test part. The test part will be made up of 30% of the tweets.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_clf, test_size=0.3, random_state=0)

# %% [markdown]
# ## Model Execution

# %%
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    ##plt.savefig('grafica.pdf')  #### EXPORTA GRÁFICA A PDF. PARA LUEGO PONERLA EN LA MEMORIA.
    return ax

# %% [markdown]
# ### Random Forest

# %%
model = RandomForestClassifier(n_estimators=1000) # Number of trees.
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print ('Acc', acc)
# Out:
# Acc 0.859448554135844

# %%
sns.set(rc={'figure.figsize':(5,5)})
plot_confusion_matrix(y_test, y_pred, classes=unique_labels(y_test, y_pred), normalize=True,
                      title='Confusion matrix')
# Out:
# Normalized confusion matrix
# [[0.04918033 0.85480094 0.09601874]
#  [0.00400209 0.95702105 0.03897686]
#  [0.00237906 0.50674068 0.49088025]]

# %% [markdown]
# ### Support Vector Machines (NO VA Y NO LO ENTIENDO.)

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'svc__C': [1, 5, 10, 50],
              'svc__gamma': [0.0001, 0.0005, 0.001, 0.005]}
grid = GridSearchCV(model, param_grid)

# %time grid.fit(X_train, y_train)
print(grid.best_params_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-a880e3de6a42> in <module>()
#       4 grid = GridSearchCV(model, param_grid)
#       5
# ----> 6 get_ipython().magic('time grid.fit(X_train, y_train)')
#       7 print(grid.best_params_)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2158         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2159         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2160         return self.run_line_magic(magic_name, magic_arg_s)
#    2161
#    2162     #-------------------------------------------------------------------------
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2079                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2080             with self.builtin_trap:
# -> 2081                 result = fn(*args,**kwargs)
#    2082             return result
#    2083
#
# <decorator-gen-60> in time(self, line, cell, local_ns)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1187         if mode=='eval':
#    1188             st = clock2()
# -> 1189             out = eval(code, glob, local_ns)
#    1190             end = clock2()
#    1191         else:
#
# <timed eval> in <module>()
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     708                 return results
#     709
# --> 710             self._run_search(evaluate_candidates)
#     711
#     712         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1149     def _run_search(self, evaluate_candidates):
#    1150         """Search all candidates in param_grid"""
# -> 1151         evaluate_candidates(ParameterGrid(self.param_grid))
#    1152
#    1153
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     687                                for parameters, (train, test)
#     688                                in product(candidate_params,
# --> 689                                           cv.split(X, y, groups)))
#     690
#     691                 if len(out) < 1:
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1039             # remaining jobs.
#    1040             self._iterating = False
# -> 1041             if self.dispatch_one_batch(iterator):
#    1042                 self._iterating = self._original_iterator is not None
#    1043
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     857                 return False
#     858             else:
# --> 859                 self._dispatch(tasks)
#     860                 return True
#     861
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in _dispatch(self, batch)
#     775         with self._lock:
#     776             job_idx = len(self._jobs)
# --> 777             job = self._backend.apply_async(batch, callback=cb)
#     778             # A job can complete so quickly than its callback is
#     779             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in <listcomp>(.0)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     502             cloned_parameters[k] = clone(v, safe=False)
#     503
# --> 504         estimator = estimator.set_params(**cloned_parameters)
#     505
#     506     start_time = time.time()
#
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py in set_params(self, **params)
#     234                                  'Check the list of available parameters '
#     235                                  'with `estimator.get_params().keys()`.' %
# --> 236                                  (key, self))
#     237
#     238             if delim:
#
# ValueError: Invalid parameter svc for estimator RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=1000,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False). Check the list of available parameters with `estimator.get_params().keys()`.

# %%
model = grid.best_estimator_
y_pred = model.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print ('Acc', acc)

# %%
plot_confusion_matrix(y_test, y_pred, classes=unique_labels(y_test, y_pred), normalize=True,
                      title='Confusion matrix')

# %% [markdown]
# ### K-nearest neighbors algorithm
#
# With this algorithm we are going to classify the tweets depending on the tweets closest to the one to be predicted.

# %%
# Number of closest tweets that you will consult.
n_neighbors = 25
weights = 'distance'
knn = KNeighborsClassifier(n_neighbors= n_neighbors, weights=weights) 
# Fit and predict
knn.fit(X = X_train, y = y_train)
y_pred = knn.predict(X = X_test)
acc = accuracy_score(y_test, y_pred)
print ('Acc', acc)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-a27ed069dd2e> in <module>()
#       5 # Fit and predict
#       6 knn.fit(X = X_train, y = y_train)
# ----> 7 y_pred = knn.predict(X = X_test)
#       8 acc = accuracy_score(y_test, y_pred)
#       9 print ('Acc', acc)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     171         X = check_array(X, accept_sparse='csr')
#     172
# --> 173         neigh_dist, neigh_ind = self.kneighbors(X)
#     174         classes_ = self.classes_
#     175         _y = self._y
#
# /usr/local/lib/python3.6/dist-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     662                 delayed_query(
#     663                     self._tree, X[s], n_neighbors, return_distance)
# --> 664                 for s in gen_even_slices(X.shape[0], n_jobs)
#     665             )
#     666         else:
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1039             # remaining jobs.
#    1040             self._iterating = False
# -> 1041             if self.dispatch_one_batch(iterator):
#    1042                 self._iterating = self._original_iterator is not None
#    1043
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     857                 return False
#     858             else:
# --> 859                 self._dispatch(tasks)
#     860                 return True
#     861
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in _dispatch(self, batch)
#     775         with self._lock:
#     776             job_idx = len(self._jobs)
# --> 777             job = self._backend.apply_async(batch, callback=cb)
#     778             # A job can complete so quickly than its callback is
#     779             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in <listcomp>(.0)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/neighbors/_base.py in _tree_query_parallel_helper(tree, *args, **kwargs)
#     489     under PyPy.
#     490     """
# --> 491     return tree.query(*args, **kwargs)
#     492
#     493
#
# KeyboardInterrupt:

# %% [markdown]
# Finally, we obtain the Confusion Matrix

# %% [markdown]
# **Confusion Matrix**

# %%
plot_confusion_matrix(y_test, y_pred, classes=unique_labels(y_test, y_pred), normalize=True,
                      title='Confusion matrix')
# Out:
# Normalized confusion matrix
# [[0.04918033 0.85480094 0.09601874]
#  [0.00400209 0.95702105 0.03897686]
#  [0.00237906 0.50674068 0.49088025]]

# %% [markdown]
# **Classification Report**

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.04      0.08       427
#            1       0.89      0.93      0.91      5747
#            2       0.64      0.71      0.67      1261
#
#     accuracy                           0.84      7435
#    macro avg       0.69      0.56      0.55      7435
# weighted avg       0.83      0.84      0.82      7435

# %% [markdown]
# ### Naive Bayes algorithm
#
# This algorithm is based on Bayes' Theorem. A Naive Bayes classifier assumes that the presence of a particular feature in a class is unrelated to the presence of any other feature.

# %%
#GaussianNB, MultinomialNB, BernoulliNB, ComplementNB
clf = BernoulliNB() # Classifier chosen
clf.fit(X_train.toarray(), y_train)
y_pred = clf.predict( X = X_test)
acc = accuracy_score(y_test, y_pred)
print ('Acc', acc)
# Out:
# Acc 0.8886348352387357

# %% [markdown]
# **Confusion Matrix**

# %%
plot_confusion_matrix(y_test, y_pred , classes = unique_labels(y_test, y_pred), normalize=True,
                      title='Normalized confusion matrix')
# Out:
# Normalized confusion matrix
# [[0.19203747 0.69086651 0.11709602]
#  [0.00783017 0.97372542 0.01844441]
#  [0.00872324 0.25455987 0.73671689]]

# %% [markdown]
# **Classification Report**

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.19      0.29       427
#            1       0.90      0.97      0.94      5747
#            2       0.86      0.74      0.79      1261
#
#     accuracy                           0.89      7435
#    macro avg       0.78      0.63      0.67      7435
# weighted avg       0.88      0.89      0.87      7435

# %% [markdown]
# ### Cross validation.

# %%
from sklearn.model_selection import ShuffleSplit

rs = ShuffleSplit(n_splits=5, test_size=.3, random_state=0, train_size=0.7)

# Number of closest tweets that you will consult.
n_neighbors = 3
weights = 'distance'
knn = KNeighborsClassifier(n_neighbors= n_neighbors, weights=weights) 
cont = 0;
for train_index, test_index in rs.split(X_new):
  rs.get_n_splits()
  print("TRAIN[",cont,"]:", train_index, "TEST[",cont,"]:", test_index)
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y_clf[train_index], y_clf[test_index]
  # Fit and predict
  knn.fit(X = X_train, y = y_train)
  y_pred = knn.predict(X = X_test.toarray())
  acc = accuracy_score(y_test, y_pred)
  print ('Acc', acc)
  cont = cont +1
  title = 'Confusion matrix ' + str(cont)
  plot_confusion_matrix(y_test, y_pred, classes=target_name, normalize=True,
                      title=title)
  print(classification_report(y_test, y_pred))

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import ShuffleSplit

rs = ShuffleSplit(n_splits=5, test_size=.3, random_state=0, train_size=0.7)

cont = 0;
for train_index, test_index in rs.split(X_new):
  rs.get_n_splits()
  print("TRAIN[",cont,"]:", train_index, "TEST[",cont,"]:", test_index)
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y_clf[train_index], y_clf[test_index]
  # Fit and predict
  #GaussianNB, MultinomialNB, BernoulliNB, ComplementNB
  clf = BernoulliNB() # Classifier chosen
  clf.fit(X_train.toarray(), y_train)
  y_pred = clf.predict(X_test.toarray())
  acc = accuracy_score(y_test, y_pred)
  print ('Acc', acc)
  cont = cont +1
  title = 'Confusion matrix ' + str(cont)
  plot_confusion_matrix(y_test, y_pred, classes=target_name, normalize=True,
                      title=title)
  print(classification_report(y_test, y_pred))

# %% [markdown]
# Once we have identified the best parameterization we will go on to make an execution of the model and we will graph its results.
